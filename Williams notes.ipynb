# %% [markdown]
# # Mapping cultural remains with LiDAR
# All forests in Sweden, both managed forests and natural old-growth forests in national parks, contain a cultural
# heritage. The long history of forest utilization in Sweden has left a rich legacy of diverse types of ancient
# monuments and other kinds of cultural remains that document our relationship with the forest and its importance
# for Sweden’s development. However, the cultural heritage is too often damaged in forestry operations. The aim of
# the project is to do research and develop operationally useful maps that can be used
# to identify, protect and enhance the cultural remains in Swedish forests, thereby reducing the destruction of
# cultural heritage in our forest landscapes.

# %% [markdown]
# ## Select LiDAR tiles which intersect field data

# %%
# !python /workspace/code/Remnants-of-charcoal-kilns/Select_study_areas.py workspace/data/charcoal_kilns/Merged_charcoal_kilns_william.shp /workspace/data/Footprint.shp /workspace/lidar/ /workspace/data/selected_dems/
# Out:
#  BlackWhite_large_zoom_wide2.png   data
#  Dockerfile			   evaluate_model.py
#  LICENSE			   inference.py
#  README.md			   inspect_distribution.py
#  Select_chips_with_labels.py	   normalize_indices.py
#  Select_study_areas.py		   post_processing.py
#  Topographical_indicies.py	   split_training_data.py
# 'Williams notes.ipynb'		   train.py
#  __pycache__			   utils
#  create_labels.py

# %%
# Tiles that intersect charcoal kilns
# !python /code/Remnants-of-charcoal-kilns/Select_study_areas.py /data/charcoal_kilns/Kolbottnar.shp /data/Footprint.shp F:/DitchNet/HalfMeterData/dem05m/ Y:/William/Kolbottnar/data/selected_dems/
# tiles that intersect hunting pits
# !python /code/Remnants-of-charcoal-kilns/Select_study_areas.py /data/charcoal_kilns/Kolbottnar.shp /data/Footprint.shp F:/DitchNet/HalfMeterData/dem05m/ Y:/William/Kolbottnar/data/selected_dems/

# %% [markdown]
# # Create training data

# %% [markdown]
# ## Create labeled images from field data

# %%
# !python /workspace/code/create_labels.py /workspace/data/selected_dems/ /workspace/data/charcoal_kilns/charcoal_kilns_buffer.shp /workspace/data/label_tiles/
# Out:
# ./whitebox_tools --run="VectorPolygonsToRaster" --input='/workspace/data/charcoal_kilns/charcoal_kilns_buffer.shp' --field=class --output='/workspace/data/label_tiles/20E018_68750_4800_25.tif' --base='/workspace/data/selected_dems/20E018_68750_4800_25.tif'
#
# *************************************
# * Welcome to VectorPolygonsToRaster *
# * Powered by WhiteboxTools          *
# * www.whiteboxgeo.com               *
# *************************************
# Reading data...
# Reading attributes: 0%
# Reading attributes: 1%
# Reading attributes: 2%
# Reading attributes: 3%
# Reading attributes: 4%
# Reading attributes: 5%
# Reading attributes: 6%
# Reading attributes: 7%
# Reading attributes: 8%
# Reading attributes: 9%
# Reading attributes: 10%
# Reading attributes: 11%
# Reading attributes: 12%
# Reading attributes: 13%
# Reading attributes: 14%
# Reading attributes: 15%
# Reading attributes: 16%
# Reading attributes: 17%
# Reading attributes: 18%
# Reading attributes: 19%
# Reading attributes: 20%
# Reading attributes: 21%
# Reading attributes: 22%
# Reading attributes: 23%
# Reading attributes: 24%
# Reading attributes: 25%
# Reading attributes: 26%
# Reading attributes: 27%
# Reading attributes: 28%
# Reading attributes: 29%
# Reading attributes: 30%
# Reading attributes: 31%
# Reading attributes: 32%
# Reading attributes: 33%
# Reading attributes: 34%
# Reading attributes: 35%
# Reading attributes: 36%
# Reading attributes: 37%
# Reading attributes: 38%
# Reading attributes: 39%
# Reading attributes: 40%
# Reading attributes: 41%
# Reading attributes: 42%
# Reading attributes: 43%
# Reading attributes: 44%
# Reading attributes: 45%
# Reading attributes: 46%
# Reading attributes: 47%
# Reading attributes: 48%
# Reading attributes: 49%
# Reading attributes: 50%
# Reading attributes: 51%
# Reading attributes: 52%
# Reading attributes: 53%
# Reading attributes: 54%
# Reading attributes: 55%
# Reading attributes: 56%
# Reading attributes: 57%
# Reading attributes: 58%
# Reading attributes: 59%
# Reading attributes: 60%
# Reading attributes: 61%
# Reading attributes: 62%
# Reading attributes: 63%
# Reading attributes: 64%
# Reading attributes: 65%
# Reading attributes: 66%
# Reading attributes: 67%
# Reading attributes: 68%
# Reading attributes: 69%
# Reading attributes: 70%
# Reading attributes: 71%
# Reading attributes: 72%
# Reading attributes: 73%
# Reading attributes: 74%
# Reading attributes: 75%
# Reading attributes: 76%
# Reading attributes: 77%
# Reading attributes: 78%
# Reading attributes: 79%
# Reading attributes: 80%
# Reading attributes: 81%
# Reading attributes: 82%
# Reading attributes: 83%
# Reading attributes: 84%
# Reading attributes: 85%
# Reading attributes: 86%
# Reading attributes: 87%
# Reading attributes: 88%
# Reading attributes: 89%
# Reading attributes: 90%
# Reading attributes: 91%
# Reading attributes: 92%
# Reading attributes: 93%
# Reading attributes: 94%
# Reading attributes: 95%
# Reading attributes: 96%
# Reading attributes: 97%
# Reading attributes: 98%
# Reading attributes: 99%
# Reading attributes: 100%
# Rasterizing 1 of 200: 0%
# Rasterizing 2 of 200: 1%
# Rasterizing 4 of 200: 2%
# Rasterizing 6 of 200: 3%
# Rasterizing 8 of 200: 4%
# Rasterizing 10 of 200: 5%
# Rasterizing 12 of 200: 6%
# Rasterizing 14 of 200: 7%
# Rasterizing 16 of 200: 8%
# Rasterizing 18 of 200: 9%
# Rasterizing 20 of 200: 10%
# Rasterizing 22 of 200: 11%
# Rasterizing 24 of 200: 12%
# Rasterizing 26 of 200: 13%
# Rasterizing 28 of 200: 14%
# Rasterizing 30 of 200: 15%
# Rasterizing 32 of 200: 16%
# Rasterizing 34 of 200: 17%
# Rasterizing 36 of 200: 18%
# Rasterizing 38 of 200: 19%
# Rasterizing 40 of 200: 20%
# Rasterizing 42 of 200: 21%
# Rasterizing 44 of 200: 22%
# Rasterizing 46 of 200: 23%
# Rasterizing 48 of 200: 24%
# Rasterizing 50 of 200: 25%
# Rasterizing 52 of 200: 26%
# Rasterizing 54 of 200: 27%
# Rasterizing 56 of 200: 28%
# Rasterizing 58 of 200: 29%
# Rasterizing 60 of 200: 30%
# Rasterizing 62 of 200: 31%
# Rasterizing 64 of 200: 32%
# Rasterizing 66 of 200: 33%
# Rasterizing 68 of 200: 34%
# Rasterizing 70 of 200: 35%
# Rasterizing 72 of 200: 36%
# Rasterizing 74 of 200: 37%
# Rasterizing 76 of 200: 38%
# Rasterizing 78 of 200: 39%
# Rasterizing 80 of 200: 40%
# Rasterizing 82 of 200: 41%
# Rasterizing 84 of 200: 42%
# Rasterizing 86 of 200: 43%
# Rasterizing 88 of 200: 44%
# Rasterizing 90 of 200: 45%
# Rasterizing 91 of 200: 11160%
# Rasterizing 91 of 200: 11163%
# Rasterizing 91 of 200: 11165%
# Rasterizing 91 of 200: 11168%
# Rasterizing 91 of 200: 11170%
# Rasterizing 91 of 200: 11173%
# Rasterizing 91 of 200: 11175%
# Rasterizing 91 of 200: 11178%
# Rasterizing 91 of 200: 11180%
# Rasterizing 91 of 200: 11182%
# Rasterizing 91 of 200: 11185%
# Rasterizing 91 of 200: 11187%
# Rasterizing 91 of 200: 11190%
# Rasterizing 91 of 200: 11192%
# Rasterizing 91 of 200: 11195%
# Rasterizing 91 of 200: 11197%
# Rasterizing 91 of 200: 11200%
# Rasterizing 91 of 200: 11202%
# Rasterizing 91 of 200: 11204%
# Rasterizing 91 of 200: 11207%
# Rasterizing 91 of 200: 11209%
# Rasterizing 91 of 200: 11212%
# Rasterizing 91 of 200: 11214%
# Rasterizing 91 of 200: 11217%
# Rasterizing 91 of 200: 11219%
# Rasterizing 91 of 200: 11221%
# Rasterizing 91 of 200: 11224%
# Rasterizing 91 of 200: 11226%
# Rasterizing 91 of 200: 11229%
# Rasterizing 91 of 200: 11231%
# Rasterizing 91 of 200: 11234%
# Rasterizing 91 of 200: 11236%
# Rasterizing 91 of 200: 11239%
# Rasterizing 91 of 200: 11241%
# Rasterizing 91 of 200: 11243%
# Rasterizing 91 of 200: 11246%
# Rasterizing 91 of 200: 11248%
# Rasterizing 91 of 200: 11251%
# Rasterizing 91 of 200: 11253%
# Rasterizing 91 of 200: 11256%
# Rasterizing 91 of 200: 11258%
# Rasterizing 91 of 200: 45%
# Rasterizing 92 of 200: 9239%
# Rasterizing 92 of 200: 9241%
# Rasterizing 92 of 200: 9244%
# Rasterizing 92 of 200: 9246%
# Rasterizing 92 of 200: 9248%
# Rasterizing 92 of 200: 9251%
# Rasterizing 92 of 200: 9253%
# Rasterizing 92 of 200: 9255%
# Rasterizing 92 of 200: 9258%
# Rasterizing 92 of 200: 9260%
# Rasterizing 92 of 200: 9262%
# Rasterizing 92 of 200: 9265%
# Rasterizing 92 of 200: 9267%
# Rasterizing 92 of 200: 9269%
# Rasterizing 92 of 200: 9272%
# Rasterizing 92 of 200: 9274%
# Rasterizing 92 of 200: 9276%
# Rasterizing 92 of 200: 9279%
# Rasterizing 92 of 200: 9281%
# Rasterizing 92 of 200: 9283%
# Rasterizing 92 of 200: 9286%
# Rasterizing 92 of 200: 9288%
# Rasterizing 92 of 200: 9290%
# Rasterizing 92 of 200: 9293%
# Rasterizing 92 of 200: 9295%
# Rasterizing 92 of 200: 9297%
# Rasterizing 92 of 200: 9300%
# Rasterizing 92 of 200: 9302%
# Rasterizing 92 of 200: 9304%
# Rasterizing 92 of 200: 9306%
# Rasterizing 92 of 200: 9309%
# Rasterizing 92 of 200: 9311%
# Rasterizing 92 of 200: 9313%
# Rasterizing 92 of 200: 9316%
# Rasterizing 92 of 200: 9318%
# Rasterizing 92 of 200: 9320%
# Rasterizing 92 of 200: 9323%
# Rasterizing 92 of 200: 9325%
# Rasterizing 92 of 200: 9327%
# Rasterizing 92 of 200: 9330%
# Rasterizing 92 of 200: 9332%
# Rasterizing 92 of 200: 9334%
# Rasterizing 92 of 200: 9337%
# Rasterizing 92 of 200: 46%
# Rasterizing 93 of 200: 2955%
# Rasterizing 93 of 200: 2957%
# Rasterizing 93 of 200: 2960%
# Rasterizing 93 of 200: 2962%
# Rasterizing 93 of 200: 2964%
# Rasterizing 93 of 200: 2966%
# Rasterizing 93 of 200: 2968%
# Rasterizing 93 of 200: 2971%
# Rasterizing 93 of 200: 2973%
# Rasterizing 93 of 200: 2975%
# Rasterizing 93 of 200: 2977%
# Rasterizing 93 of 200: 2980%
# Rasterizing 93 of 200: 2982%
# Rasterizing 93 of 200: 2984%
# Rasterizing 93 of 200: 2986%
# Rasterizing 93 of 200: 2988%
# Rasterizing 93 of 200: 2991%
# Rasterizing 93 of 200: 2993%
# Rasterizing 93 of 200: 2995%
# Rasterizing 93 of 200: 2997%
# Rasterizing 93 of 200: 3000%
# Rasterizing 93 of 200: 3002%
# Rasterizing 93 of 200: 3004%
# Rasterizing 93 of 200: 3006%
# Rasterizing 93 of 200: 3008%
# Rasterizing 93 of 200: 3011%
# Rasterizing 93 of 200: 3013%
# Rasterizing 93 of 200: 3015%
# Rasterizing 93 of 200: 3017%
# Rasterizing 93 of 200: 3020%
# Rasterizing 93 of 200: 3022%
# Rasterizing 93 of 200: 3024%
# Rasterizing 93 of 200: 3026%
# Rasterizing 93 of 200: 3028%
# Rasterizing 93 of 200: 3031%
# Rasterizing 93 of 200: 3033%
# Rasterizing 93 of 200: 3035%
# Rasterizing 93 of 200: 3037%
# Rasterizing 93 of 200: 3040%
# Rasterizing 93 of 200: 3042%
# Rasterizing 93 of 200: 3044%
# Rasterizing 93 of 200: 3046%
# Rasterizing 93 of 200: 3048%
# Rasterizing 93 of 200: 3051%
# Rasterizing 93 of 200: 3053%
# Rasterizing 93 of 200: 46%
# Rasterizing 94 of 200: 47%
# Rasterizing 96 of 200: 48%
# Rasterizing 98 of 200: 49%
# Rasterizing 100 of 200: 50%
# Rasterizing 102 of 200: 51%
# Rasterizing 104 of 200: 52%
# Rasterizing 106 of 200: 53%
# Rasterizing 108 of 200: 54%
# Rasterizing 110 of 200: 55%
# Rasterizing 112 of 200: 56%
# Rasterizing 114 of 200: 57%
# Rasterizing 116 of 200: 58%
# Rasterizing 118 of 200: 59%
# Rasterizing 120 of 200: 60%
# Rasterizing 122 of 200: 61%
# Rasterizing 124 of 200: 62%
# Rasterizing 126 of 200: 63%
# Rasterizing 128 of 200: 64%
# Rasterizing 130 of 200: 65%
# Rasterizing 132 of 200: 66%
# Rasterizing 134 of 200: 67%
# Rasterizing 136 of 200: 68%
# Rasterizing 138 of 200: 69%
# Rasterizing 140 of 200: 70%
# Rasterizing 142 of 200: 71%
# Rasterizing 144 of 200: 72%
# Rasterizing 146 of 200: 73%
# Rasterizing 148 of 200: 74%
# Rasterizing 150 of 200: 75%
# Rasterizing 152 of 200: 76%
# Rasterizing 154 of 200: 77%
# Rasterizing 156 of 200: 78%
# Rasterizing 158 of 200: 79%
# Rasterizing 160 of 200: 80%
# Rasterizing 162 of 200: 81%
# Rasterizing 164 of 200: 82%
# Rasterizing 166 of 200: 83%
# Rasterizing 168 of 200: 84%
# Rasterizing 170 of 200: 85%
# Rasterizing 172 of 200: 86%
# Rasterizing 174 of 200: 87%
# Rasterizing 176 of 200: 88%
# Rasterizing 178 of 200: 89%
# Rasterizing 180 of 200: 90%
# Rasterizing 182 of 200: 91%
# Rasterizing 184 of 200: 6132%
# Rasterizing 184 of 200: 6136%
# Rasterizing 184 of 200: 6140%
# Rasterizing 184 of 200: 6144%
# Rasterizing 184 of 200: 6148%
# Rasterizing 184 of 200: 6152%
# Rasterizing 184 of 200: 6156%
# Rasterizing 184 of 200: 6160%
# Rasterizing 184 of 200: 6164%
# Rasterizing 184 of 200: 6168%
# Rasterizing 184 of 200: 6172%
# Rasterizing 184 of 200: 6176%
# Rasterizing 184 of 200: 6180%
# Rasterizing 184 of 200: 6184%
# Rasterizing 184 of 200: 6188%
# Rasterizing 184 of 200: 6192%
# Rasterizing 184 of 200: 6196%
# Rasterizing 184 of 200: 6200%
# Rasterizing 184 of 200: 6204%
# Rasterizing 184 of 200: 6208%
# Rasterizing 184 of 200: 6212%
# Rasterizing 184 of 200: 6216%
# Rasterizing 184 of 200: 6220%
# Rasterizing 184 of 200: 6224%
# Rasterizing 184 of 200: 6228%
# Rasterizing 184 of 200: 92%
# Rasterizing 185 of 200: 4682%
# Rasterizing 185 of 200: 4685%
# Rasterizing 185 of 200: 4687%
# Rasterizing 185 of 200: 4690%
# Rasterizing 185 of 200: 4692%
# Rasterizing 185 of 200: 4695%
# Rasterizing 185 of 200: 4697%
# Rasterizing 185 of 200: 4700%
# Rasterizing 185 of 200: 4702%
# Rasterizing 185 of 200: 4704%
# Rasterizing 185 of 200: 4707%
# Rasterizing 185 of 200: 4709%
# Rasterizing 185 of 200: 4712%
# Rasterizing 185 of 200: 4714%
# Rasterizing 185 of 200: 4717%
# Rasterizing 185 of 200: 4719%
# Rasterizing 185 of 200: 4721%
# Rasterizing 185 of 200: 4724%
# Rasterizing 185 of 200: 4726%
# Rasterizing 185 of 200: 4729%
# Rasterizing 185 of 200: 4731%
# Rasterizing 185 of 200: 4734%
# Rasterizing 185 of 200: 4736%
# Rasterizing 185 of 200: 4739%
# Rasterizing 185 of 200: 4741%
# Rasterizing 185 of 200: 4743%
# Rasterizing 185 of 200: 4746%
# Rasterizing 185 of 200: 4748%
# Rasterizing 185 of 200: 4751%
# Rasterizing 185 of 200: 4753%
# Rasterizing 185 of 200: 4756%
# Rasterizing 185 of 200: 4758%
# Rasterizing 185 of 200: 4760%
# Rasterizing 185 of 200: 4763%
# Rasterizing 185 of 200: 4765%
# Rasterizing 185 of 200: 4768%
# Rasterizing 185 of 200: 4770%
# Rasterizing 185 of 200: 4773%
# Rasterizing 185 of 200: 4775%
# Rasterizing 185 of 200: 4778%
# Rasterizing 185 of 200: 4780%
# Rasterizing 185 of 200: 92%
# Rasterizing 186 of 200: 10097%
# Rasterizing 186 of 200: 10100%
# Rasterizing 186 of 200: 10102%
# Rasterizing 186 of 200: 10104%
# Rasterizing 186 of 200: 10107%
# Rasterizing 186 of 200: 10109%
# Rasterizing 186 of 200: 10112%
# Rasterizing 186 of 200: 10114%
# Rasterizing 186 of 200: 10117%
# Rasterizing 186 of 200: 10119%
# Rasterizing 186 of 200: 10121%
# Rasterizing 186 of 200: 10124%
# Rasterizing 186 of 200: 10126%
# Rasterizing 186 of 200: 10129%
# Rasterizing 186 of 200: 10131%
# Rasterizing 186 of 200: 10134%
# Rasterizing 186 of 200: 10136%
# Rasterizing 186 of 200: 10139%
# Rasterizing 186 of 200: 10141%
# Rasterizing 186 of 200: 10143%
# Rasterizing 186 of 200: 10146%
# Rasterizing 186 of 200: 10148%
# Rasterizing 186 of 200: 10151%
# Rasterizing 186 of 200: 10153%
# Rasterizing 186 of 200: 10156%
# Rasterizing 186 of 200: 10158%
# Rasterizing 186 of 200: 10160%
# Rasterizing 186 of 200: 10163%
# Rasterizing 186 of 200: 10165%
# Rasterizing 186 of 200: 10168%
# Rasterizing 186 of 200: 10170%
# Rasterizing 186 of 200: 10173%
# Rasterizing 186 of 200: 10175%
# Rasterizing 186 of 200: 10178%
# Rasterizing 186 of 200: 10180%
# Rasterizing 186 of 200: 10182%
# Rasterizing 186 of 200: 10185%
# Rasterizing 186 of 200: 10187%
# Rasterizing 186 of 200: 10190%
# Rasterizing 186 of 200: 10192%
# Rasterizing 186 of 200: 10195%
# Rasterizing 186 of 200: 93%
# Rasterizing 187 of 200: 9551%
# Rasterizing 187 of 200: 9554%
# Rasterizing 187 of 200: 9556%
# Rasterizing 187 of 200: 9559%
# Rasterizing 187 of 200: 9562%
# Rasterizing 187 of 200: 9564%
# Rasterizing 187 of 200: 9567%
# Rasterizing 187 of 200: 9570%
# Rasterizing 187 of 200: 9572%
# Rasterizing 187 of 200: 9575%
# Rasterizing 187 of 200: 9578%
# Rasterizing 187 of 200: 9581%
# Rasterizing 187 of 200: 9583%
# Rasterizing 187 of 200: 9586%
# Rasterizing 187 of 200: 9589%
# Rasterizing 187 of 200: 9591%
# Rasterizing 187 of 200: 9594%
# Rasterizing 187 of 200: 9597%
# Rasterizing 187 of 200: 9600%
# Rasterizing 187 of 200: 9602%
# Rasterizing 187 of 200: 9605%
# Rasterizing 187 of 200: 9608%
# Rasterizing 187 of 200: 9610%
# Rasterizing 187 of 200: 9613%
# Rasterizing 187 of 200: 9616%
# Rasterizing 187 of 200: 9618%
# Rasterizing 187 of 200: 9621%
# Rasterizing 187 of 200: 9624%
# Rasterizing 187 of 200: 9627%
# Rasterizing 187 of 200: 9629%
# Rasterizing 187 of 200: 9632%
# Rasterizing 187 of 200: 9635%
# Rasterizing 187 of 200: 9637%
# Rasterizing 187 of 200: 9640%
# Rasterizing 187 of 200: 9643%
# Rasterizing 187 of 200: 9645%
# Rasterizing 187 of 200: 9648%
# Rasterizing 187 of 200: 93%
# Rasterizing 188 of 200: 6958%
# Rasterizing 188 of 200: 6960%
# Rasterizing 188 of 200: 6963%
# Rasterizing 188 of 200: 6965%
# Rasterizing 188 of 200: 6968%
# Rasterizing 188 of 200: 6970%
# Rasterizing 188 of 200: 6973%
# Rasterizing 188 of 200: 6975%
# Rasterizing 188 of 200: 6978%
# Rasterizing 188 of 200: 6980%
# Rasterizing 188 of 200: 6982%
# Rasterizing 188 of 200: 6985%
# Rasterizing 188 of 200: 6987%
# Rasterizing 188 of 200: 6990%
# Rasterizing 188 of 200: 6992%
# Rasterizing 188 of 200: 6995%
# Rasterizing 188 of 200: 6997%
# Rasterizing 188 of 200: 7000%
# Rasterizing 188 of 200: 7002%
# Rasterizing 188 of 200: 7004%
# Rasterizing 188 of 200: 7007%
# Rasterizing 188 of 200: 7009%
# Rasterizing 188 of 200: 7012%
# Rasterizing 188 of 200: 7014%
# Rasterizing 188 of 200: 7017%
# Rasterizing 188 of 200: 7019%
# Rasterizing 188 of 200: 7021%
# Rasterizing 188 of 200: 7024%
# Rasterizing 188 of 200: 7026%
# Rasterizing 188 of 200: 7029%
# Rasterizing 188 of 200: 7031%
# Rasterizing 188 of 200: 7034%
# Rasterizing 188 of 200: 7036%
# Rasterizing 188 of 200: 7039%
# Rasterizing 188 of 200: 7041%
# Rasterizing 188 of 200: 7043%
# Rasterizing 188 of 200: 7046%
# Rasterizing 188 of 200: 7048%
# Rasterizing 188 of 200: 7051%
# Rasterizing 188 of 200: 7053%
# Rasterizing 188 of 200: 7056%
# Rasterizing 188 of 200: 94%
# Rasterizing 189 of 200: 5807%
# Rasterizing 189 of 200: 5809%
# Rasterizing 189 of 200: 5812%
# Rasterizing 189 of 200: 5814%
# Rasterizing 189 of 200: 5817%
# Rasterizing 189 of 200: 5819%
# Rasterizing 189 of 200: 5821%
# Rasterizing 189 of 200: 5824%
# Rasterizing 189 of 200: 5826%
# Rasterizing 189 of 200: 5829%
# Rasterizing 189 of 200: 5831%
# Rasterizing 189 of 200: 5834%
# Rasterizing 189 of 200: 5836%
# Rasterizing 189 of 200: 5839%
# Rasterizing 189 of 200: 5841%
# Rasterizing 189 of 200: 5843%
# Rasterizing 189 of 200: 5846%
# Rasterizing 189 of 200: 5848%
# Rasterizing 189 of 200: 5851%
# Rasterizing 189 of 200: 5853%
# Rasterizing 189 of 200: 5856%
# Rasterizing 189 of 200: 5858%
# Rasterizing 189 of 200: 5860%
# Rasterizing 189 of 200: 5863%
# Rasterizing 189 of 200: 5865%
# Rasterizing 189 of 200: 5868%
# Rasterizing 189 of 200: 5870%
# Rasterizing 189 of 200: 5873%
# Rasterizing 189 of 200: 5875%
# Rasterizing 189 of 200: 5878%
# Rasterizing 189 of 200: 5880%
# Rasterizing 189 of 200: 5882%
# Rasterizing 189 of 200: 5885%
# Rasterizing 189 of 200: 5887%
# Rasterizing 189 of 200: 5890%
# Rasterizing 189 of 200: 5892%
# Rasterizing 189 of 200: 5895%
# Rasterizing 189 of 200: 5897%
# Rasterizing 189 of 200: 5900%
# Rasterizing 189 of 200: 5902%
# Rasterizing 189 of 200: 5904%
# Rasterizing 189 of 200: 94%
# Rasterizing 190 of 200: 8568%
# Rasterizing 190 of 200: 8571%
# Rasterizing 190 of 200: 8573%
# Rasterizing 190 of 200: 8575%
# Rasterizing 190 of 200: 8577%
# Rasterizing 190 of 200: 8580%
# Rasterizing 190 of 200: 8582%
# Rasterizing 190 of 200: 8584%
# Rasterizing 190 of 200: 8586%
# Rasterizing 190 of 200: 8588%
# Rasterizing 190 of 200: 8591%
# Rasterizing 190 of 200: 8593%
# Rasterizing 190 of 200: 8595%
# Rasterizing 190 of 200: 8597%
# Rasterizing 190 of 200: 8600%
# Rasterizing 190 of 200: 8602%
# Rasterizing 190 of 200: 8604%
# Rasterizing 190 of 200: 8606%
# Rasterizing 190 of 200: 8608%
# Rasterizing 190 of 200: 8611%
# Rasterizing 190 of 200: 8613%
# Rasterizing 190 of 200: 8615%
# Rasterizing 190 of 200: 8617%
# Rasterizing 190 of 200: 8620%
# Rasterizing 190 of 200: 8622%
# Rasterizing 190 of 200: 8624%
# Rasterizing 190 of 200: 8626%
# Rasterizing 190 of 200: 8628%
# Rasterizing 190 of 200: 8631%
# Rasterizing 190 of 200: 8633%
# Rasterizing 190 of 200: 8635%
# Rasterizing 190 of 200: 8637%
# Rasterizing 190 of 200: 8640%
# Rasterizing 190 of 200: 8642%
# Rasterizing 190 of 200: 8644%
# Rasterizing 190 of 200: 8646%
# Rasterizing 190 of 200: 8648%
# Rasterizing 190 of 200: 8651%
# Rasterizing 190 of 200: 8653%
# Rasterizing 190 of 200: 8655%
# Rasterizing 190 of 200: 8657%
# Rasterizing 190 of 200: 8660%
# Rasterizing 190 of 200: 8662%
# Rasterizing 190 of 200: 8664%
# Rasterizing 190 of 200: 8666%
# Rasterizing 190 of 200: 95%
# Rasterizing 191 of 200: 9535%
# Rasterizing 191 of 200: 9537%
# Rasterizing 191 of 200: 9540%
# Rasterizing 191 of 200: 9542%
# Rasterizing 191 of 200: 9544%
# Rasterizing 191 of 200: 9546%
# Rasterizing 191 of 200: 9548%
# Rasterizing 191 of 200: 9551%
# Rasterizing 191 of 200: 9553%
# Rasterizing 191 of 200: 9555%
# Rasterizing 191 of 200: 9557%
# Rasterizing 191 of 200: 9560%
# Rasterizing 191 of 200: 9562%
# Rasterizing 191 of 200: 9564%
# Rasterizing 191 of 200: 9566%
# Rasterizing 191 of 200: 9568%
# Rasterizing 191 of 200: 9571%
# Rasterizing 191 of 200: 9573%
# Rasterizing 191 of 200: 9575%
# Rasterizing 191 of 200: 9577%
# Rasterizing 191 of 200: 9580%
# Rasterizing 191 of 200: 9582%
# Rasterizing 191 of 200: 9584%
# Rasterizing 191 of 200: 9586%
# Rasterizing 191 of 200: 9588%
# Rasterizing 191 of 200: 9591%
# Rasterizing 191 of 200: 9593%
# Rasterizing 191 of 200: 9595%
# Rasterizing 191 of 200: 9597%
# Rasterizing 191 of 200: 9600%
# Rasterizing 191 of 200: 9602%
# Rasterizing 191 of 200: 9604%
# Rasterizing 191 of 200: 9606%
# Rasterizing 191 of 200: 9608%
# Rasterizing 191 of 200: 9611%
# Rasterizing 191 of 200: 9613%
# Rasterizing 191 of 200: 9615%
# Rasterizing 191 of 200: 9617%
# Rasterizing 191 of 200: 9620%
# Rasterizing 191 of 200: 9622%
# Rasterizing 191 of 200: 9624%
# Rasterizing 191 of 200: 9626%
# Rasterizing 191 of 200: 9628%
# Rasterizing 191 of 200: 9631%
# Rasterizing 191 of 200: 9633%
# Rasterizing 191 of 200: 95%
# Rasterizing 192 of 200: 9822%
# Rasterizing 192 of 200: 9824%
# Rasterizing 192 of 200: 9826%
# Rasterizing 192 of 200: 9828%
# Rasterizing 192 of 200: 9831%
# Rasterizing 192 of 200: 9833%
# Rasterizing 192 of 200: 9835%
# Rasterizing 192 of 200: 9837%
# Rasterizing 192 of 200: 9840%
# Rasterizing 192 of 200: 9842%
# Rasterizing 192 of 200: 9844%
# Rasterizing 192 of 200: 9846%
# Rasterizing 192 of 200: 9848%
# Rasterizing 192 of 200: 9851%
# Rasterizing 192 of 200: 9853%
# Rasterizing 192 of 200: 9855%
# Rasterizing 192 of 200: 9857%
# Rasterizing 192 of 200: 9860%
# Rasterizing 192 of 200: 9862%
# Rasterizing 192 of 200: 9864%
# Rasterizing 192 of 200: 9866%
# Rasterizing 192 of 200: 9868%
# Rasterizing 192 of 200: 9871%
# Rasterizing 192 of 200: 9873%
# Rasterizing 192 of 200: 9875%
# Rasterizing 192 of 200: 9877%
# Rasterizing 192 of 200: 9880%
# Rasterizing 192 of 200: 9882%
# Rasterizing 192 of 200: 9884%
# Rasterizing 192 of 200: 9886%
# Rasterizing 192 of 200: 9888%
# Rasterizing 192 of 200: 9891%
# Rasterizing 192 of 200: 9893%
# Rasterizing 192 of 200: 9895%
# Rasterizing 192 of 200: 9897%
# Rasterizing 192 of 200: 9900%
# Rasterizing 192 of 200: 9902%
# Rasterizing 192 of 200: 9904%
# Rasterizing 192 of 200: 9906%
# Rasterizing 192 of 200: 9908%
# Rasterizing 192 of 200: 9911%
# Rasterizing 192 of 200: 9913%
# Rasterizing 192 of 200: 9915%
# Rasterizing 192 of 200: 9917%
# Rasterizing 192 of 200: 9920%
# Rasterizing 192 of 200: 96%
# Rasterizing 193 of 200: 12836%
# Rasterizing 193 of 200: 12839%
# Rasterizing 193 of 200: 12842%
# Rasterizing 193 of 200: 12845%
# Rasterizing 193 of 200: 12848%
# Rasterizing 193 of 200: 12851%
# Rasterizing 193 of 200: 12854%
# Rasterizing 193 of 200: 12857%
# Rasterizing 193 of 200: 12860%
# Rasterizing 193 of 200: 12863%
# Rasterizing 193 of 200: 12866%
# Rasterizing 193 of 200: 12869%
# Rasterizing 193 of 200: 12872%
# Rasterizing 193 of 200: 12875%
# Rasterizing 193 of 200: 12878%
# Rasterizing 193 of 200: 12881%
# Rasterizing 193 of 200: 12884%
# Rasterizing 193 of 200: 12887%
# Rasterizing 193 of 200: 12890%
# Rasterizing 193 of 200: 12893%
# Rasterizing 193 of 200: 12896%
# Rasterizing 193 of 200: 12900%
# Rasterizing 193 of 200: 12903%
# Rasterizing 193 of 200: 12906%
# Rasterizing 193 of 200: 12909%
# Rasterizing 193 of 200: 12912%
# Rasterizing 193 of 200: 12915%
# Rasterizing 193 of 200: 12918%
# Rasterizing 193 of 200: 12921%
# Rasterizing 193 of 200: 12924%
# Rasterizing 193 of 200: 12927%
# Rasterizing 193 of 200: 12930%
# Rasterizing 193 of 200: 12933%
# Rasterizing 193 of 200: 96%
# Rasterizing 194 of 200: 7348%
# Rasterizing 194 of 200: 7351%
# Rasterizing 194 of 200: 7354%
# Rasterizing 194 of 200: 7356%
# Rasterizing 194 of 200: 7359%
# Rasterizing 194 of 200: 7362%
# Rasterizing 194 of 200: 7364%
# Rasterizing 194 of 200: 7367%
# Rasterizing 194 of 200: 7370%
# Rasterizing 194 of 200: 7372%
# Rasterizing 194 of 200: 7375%
# Rasterizing 194 of 200: 7378%
# Rasterizing 194 of 200: 7381%
# Rasterizing 194 of 200: 7383%
# Rasterizing 194 of 200: 7386%
# Rasterizing 194 of 200: 7389%
# Rasterizing 194 of 200: 7391%
# Rasterizing 194 of 200: 7394%
# Rasterizing 194 of 200: 7397%
# Rasterizing 194 of 200: 7400%
# Rasterizing 194 of 200: 7402%
# Rasterizing 194 of 200: 7405%
# Rasterizing 194 of 200: 7408%
# Rasterizing 194 of 200: 7410%
# Rasterizing 194 of 200: 7413%
# Rasterizing 194 of 200: 7416%
# Rasterizing 194 of 200: 7418%
# Rasterizing 194 of 200: 7421%
# Rasterizing 194 of 200: 7424%
# Rasterizing 194 of 200: 7427%
# Rasterizing 194 of 200: 7429%
# Rasterizing 194 of 200: 7432%
# Rasterizing 194 of 200: 7435%
# Rasterizing 194 of 200: 7437%
# Rasterizing 194 of 200: 7440%
# Rasterizing 194 of 200: 7443%
# Rasterizing 194 of 200: 7445%
# Rasterizing 194 of 200: 97%
# Rasterizing 195 of 200: 2353%
# Rasterizing 195 of 200: 2356%
# Rasterizing 195 of 200: 2358%
# Rasterizing 195 of 200: 2361%
# Rasterizing 195 of 200: 2364%
# Rasterizing 195 of 200: 2366%
# Rasterizing 195 of 200: 2369%
# Rasterizing 195 of 200: 2371%
# Rasterizing 195 of 200: 2374%
# Rasterizing 195 of 200: 2376%
# Rasterizing 195 of 200: 2379%
# Rasterizing 195 of 200: 2382%
# Rasterizing 195 of 200: 2384%
# Rasterizing 195 of 200: 2387%
# Rasterizing 195 of 200: 2389%
# Rasterizing 195 of 200: 2392%
# Rasterizing 195 of 200: 2394%
# Rasterizing 195 of 200: 2397%
# Rasterizing 195 of 200: 2400%
# Rasterizing 195 of 200: 2402%
# Rasterizing 195 of 200: 2405%
# Rasterizing 195 of 200: 2407%
# Rasterizing 195 of 200: 2410%
# Rasterizing 195 of 200: 2412%
# Rasterizing 195 of 200: 2415%
# Rasterizing 195 of 200: 2417%
# Rasterizing 195 of 200: 2420%
# Rasterizing 195 of 200: 2423%
# Rasterizing 195 of 200: 2425%
# Rasterizing 195 of 200: 2428%
# Rasterizing 195 of 200: 2430%
# Rasterizing 195 of 200: 2433%
# Rasterizing 195 of 200: 2435%
# Rasterizing 195 of 200: 2438%
# Rasterizing 195 of 200: 2441%
# Rasterizing 195 of 200: 2443%
# Rasterizing 195 of 200: 2446%
# Rasterizing 195 of 200: 2448%
# Rasterizing 195 of 200: 2451%
# Rasterizing 195 of 200: 97%
# Rasterizing 196 of 200: 98%
# Rasterizing 198 of 200: 99%
# Rasterizing 200 of 200: 100%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.667s
# ./whitebox_tools --run="VectorPolygonsToRaster" --input='/workspace/data/charcoal_kilns/charcoal_kilns_buffer.shp' --field=class --output='/workspace/data/label_tiles/20E018_68775_4775_25.tif' --base='/workspace/data/selected_dems/20E018_68775_4775_25.tif'
#
# *************************************
# * Welcome to VectorPolygonsToRaster *
# * Powered by WhiteboxTools          *
# * www.whiteboxgeo.com               *
# *************************************
# Reading data...
# Reading attributes: 0%
# Reading attributes: 1%
# Reading attributes: 2%
# Reading attributes: 3%
# Reading attributes: 4%
# Reading attributes: 5%
# Reading attributes: 6%
# Reading attributes: 7%
# Reading attributes: 8%
# Reading attributes: 9%
# Reading attributes: 10%
# Reading attributes: 11%
# Reading attributes: 12%
# Reading attributes: 13%
# Reading attributes: 14%
# Reading attributes: 15%
# Reading attributes: 16%
# Reading attributes: 17%
# Reading attributes: 18%
# Reading attributes: 19%
# Reading attributes: 20%
# Reading attributes: 21%
# Reading attributes: 22%
# Reading attributes: 23%
# Reading attributes: 24%
# Reading attributes: 25%
# Reading attributes: 26%
# Reading attributes: 27%
# Reading attributes: 28%
# Reading attributes: 29%
# Reading attributes: 30%
# Reading attributes: 31%
# Reading attributes: 32%
# Reading attributes: 33%
# Reading attributes: 34%
# Reading attributes: 35%
# Reading attributes: 36%
# Reading attributes: 37%
# Reading attributes: 38%
# Reading attributes: 39%
# Reading attributes: 40%
# Reading attributes: 41%
# Reading attributes: 42%
# Reading attributes: 43%
# Reading attributes: 44%
# Reading attributes: 45%
# Reading attributes: 46%
# Reading attributes: 47%
# Reading attributes: 48%
# Reading attributes: 49%
# Reading attributes: 50%
# Reading attributes: 51%
# Reading attributes: 52%
# Reading attributes: 53%
# Reading attributes: 54%
# Reading attributes: 55%
# Reading attributes: 56%
# Reading attributes: 57%
# Reading attributes: 58%
# Reading attributes: 59%
# Reading attributes: 60%
# Reading attributes: 61%
# Reading attributes: 62%
# Reading attributes: 63%
# Reading attributes: 64%
# Reading attributes: 65%
# Reading attributes: 66%
# Reading attributes: 67%
# Reading attributes: 68%
# Reading attributes: 69%
# Reading attributes: 70%
# Reading attributes: 71%
# Reading attributes: 72%
# Reading attributes: 73%
# Reading attributes: 74%
# Reading attributes: 75%
# Reading attributes: 76%
# Reading attributes: 77%
# Reading attributes: 78%
# Reading attributes: 79%
# Reading attributes: 80%
# Reading attributes: 81%
# Reading attributes: 82%
# Reading attributes: 83%
# Reading attributes: 84%
# Reading attributes: 85%
# Reading attributes: 86%
# Reading attributes: 87%
# Reading attributes: 88%
# Reading attributes: 89%
# Reading attributes: 90%
# Reading attributes: 91%
# Reading attributes: 92%
# Reading attributes: 93%
# Reading attributes: 94%
# Reading attributes: 95%
# Reading attributes: 96%
# Reading attributes: 97%
# Reading attributes: 98%
# Reading attributes: 99%
# Reading attributes: 100%
# Rasterizing 1 of 200: 0%
# Rasterizing 2 of 200: 1%
# Rasterizing 4 of 200: 2%
# Rasterizing 6 of 200: 3%
# Rasterizing 8 of 200: 4%
# Rasterizing 10 of 200: 5%
# Rasterizing 12 of 200: 6%
# Rasterizing 14 of 200: 7%
# Rasterizing 16 of 200: 8%
# Rasterizing 18 of 200: 9%
# Rasterizing 20 of 200: 10%
# Rasterizing 22 of 200: 11%
# Rasterizing 24 of 200: 12%
# Rasterizing 26 of 200: 13%
# Rasterizing 28 of 200: 14%
# Rasterizing 30 of 200: 15%
# Rasterizing 32 of 200: 16%
# Rasterizing 34 of 200: 17%
# Rasterizing 36 of 200: 18%
# Rasterizing 38 of 200: 19%
# Rasterizing 40 of 200: 20%
# Rasterizing 42 of 200: 21%
# Rasterizing 44 of 200: 22%
# Rasterizing 46 of 200: 23%
# Rasterizing 48 of 200: 24%
# Rasterizing 50 of 200: 25%
# Rasterizing 52 of 200: 26%
# Rasterizing 54 of 200: 27%
# Rasterizing 56 of 200: 28%
# Rasterizing 58 of 200: 29%
# Rasterizing 60 of 200: 30%
# Rasterizing 62 of 200: 31%
# Rasterizing 64 of 200: 32%
# Rasterizing 66 of 200: 33%
# Rasterizing 68 of 200: 34%
# Rasterizing 70 of 200: 35%
# Rasterizing 72 of 200: 36%
# Rasterizing 74 of 200: 37%
# Rasterizing 76 of 200: 38%
# Rasterizing 78 of 200: 39%
# Rasterizing 80 of 200: 40%
# Rasterizing 82 of 200: 41%
# Rasterizing 84 of 200: 42%
# Rasterizing 86 of 200: 43%
# Rasterizing 88 of 200: 44%
# Rasterizing 89 of 200: 12130%
# Rasterizing 89 of 200: 12133%
# Rasterizing 89 of 200: 12135%
# Rasterizing 89 of 200: 12138%
# Rasterizing 89 of 200: 12141%
# Rasterizing 89 of 200: 12143%
# Rasterizing 89 of 200: 12146%
# Rasterizing 89 of 200: 12148%
# Rasterizing 89 of 200: 12151%
# Rasterizing 89 of 200: 12153%
# Rasterizing 89 of 200: 12156%
# Rasterizing 89 of 200: 12158%
# Rasterizing 89 of 200: 12161%
# Rasterizing 89 of 200: 12164%
# Rasterizing 89 of 200: 12166%
# Rasterizing 89 of 200: 12169%
# Rasterizing 89 of 200: 12171%
# Rasterizing 89 of 200: 12174%
# Rasterizing 89 of 200: 12176%
# Rasterizing 89 of 200: 12179%
# Rasterizing 89 of 200: 12182%
# Rasterizing 89 of 200: 12184%
# Rasterizing 89 of 200: 12187%
# Rasterizing 89 of 200: 12189%
# Rasterizing 89 of 200: 12192%
# Rasterizing 89 of 200: 12194%
# Rasterizing 89 of 200: 12197%
# Rasterizing 89 of 200: 12200%
# Rasterizing 89 of 200: 12202%
# Rasterizing 89 of 200: 12205%
# Rasterizing 89 of 200: 12207%
# Rasterizing 89 of 200: 12210%
# Rasterizing 89 of 200: 12212%
# Rasterizing 89 of 200: 12215%
# Rasterizing 89 of 200: 12217%
# Rasterizing 89 of 200: 12220%
# Rasterizing 89 of 200: 12223%
# Rasterizing 89 of 200: 12225%
# Rasterizing 89 of 200: 12228%
# Rasterizing 89 of 200: 44%
# Rasterizing 90 of 200: 11229%
# Rasterizing 90 of 200: 11231%
# Rasterizing 90 of 200: 11234%
# Rasterizing 90 of 200: 11236%
# Rasterizing 90 of 200: 11239%
# Rasterizing 90 of 200: 11241%
# Rasterizing 90 of 200: 11243%
# Rasterizing 90 of 200: 11246%
# Rasterizing 90 of 200: 11248%
# Rasterizing 90 of 200: 11251%
# Rasterizing 90 of 200: 11253%
# Rasterizing 90 of 200: 11256%
# Rasterizing 90 of 200: 11258%
# Rasterizing 90 of 200: 11260%
# Rasterizing 90 of 200: 11263%
# Rasterizing 90 of 200: 11265%
# Rasterizing 90 of 200: 11268%
# Rasterizing 90 of 200: 11270%
# Rasterizing 90 of 200: 11273%
# Rasterizing 90 of 200: 11275%
# Rasterizing 90 of 200: 11278%
# Rasterizing 90 of 200: 11280%
# Rasterizing 90 of 200: 11282%
# Rasterizing 90 of 200: 11285%
# Rasterizing 90 of 200: 11287%
# Rasterizing 90 of 200: 11290%
# Rasterizing 90 of 200: 11292%
# Rasterizing 90 of 200: 11295%
# Rasterizing 90 of 200: 11297%
# Rasterizing 90 of 200: 11300%
# Rasterizing 90 of 200: 11302%
# Rasterizing 90 of 200: 11304%
# Rasterizing 90 of 200: 11307%
# Rasterizing 90 of 200: 11309%
# Rasterizing 90 of 200: 11312%
# Rasterizing 90 of 200: 11314%
# Rasterizing 90 of 200: 11317%
# Rasterizing 90 of 200: 11319%
# Rasterizing 90 of 200: 11321%
# Rasterizing 90 of 200: 11324%
# Rasterizing 90 of 200: 11326%
# Rasterizing 90 of 200: 45%
# Rasterizing 92 of 200: 46%
# Rasterizing 94 of 200: 12094%
# Rasterizing 94 of 200: 12097%
# Rasterizing 94 of 200: 12100%
# Rasterizing 94 of 200: 12102%
# Rasterizing 94 of 200: 12105%
# Rasterizing 94 of 200: 12108%
# Rasterizing 94 of 200: 12110%
# Rasterizing 94 of 200: 12113%
# Rasterizing 94 of 200: 12116%
# Rasterizing 94 of 200: 12118%
# Rasterizing 94 of 200: 12121%
# Rasterizing 94 of 200: 12124%
# Rasterizing 94 of 200: 12127%
# Rasterizing 94 of 200: 12129%
# Rasterizing 94 of 200: 12132%
# Rasterizing 94 of 200: 12135%
# Rasterizing 94 of 200: 12137%
# Rasterizing 94 of 200: 12140%
# Rasterizing 94 of 200: 12143%
# Rasterizing 94 of 200: 12145%
# Rasterizing 94 of 200: 12148%
# Rasterizing 94 of 200: 12151%
# Rasterizing 94 of 200: 12154%
# Rasterizing 94 of 200: 12156%
# Rasterizing 94 of 200: 12159%
# Rasterizing 94 of 200: 12162%
# Rasterizing 94 of 200: 12164%
# Rasterizing 94 of 200: 12167%
# Rasterizing 94 of 200: 12170%
# Rasterizing 94 of 200: 12172%
# Rasterizing 94 of 200: 12175%
# Rasterizing 94 of 200: 12178%
# Rasterizing 94 of 200: 12181%
# Rasterizing 94 of 200: 12183%
# Rasterizing 94 of 200: 12186%
# Rasterizing 94 of 200: 12189%
# Rasterizing 94 of 200: 12191%
# Rasterizing 94 of 200: 47%
# Rasterizing 95 of 200: 9927%
# Rasterizing 95 of 200: 9930%
# Rasterizing 95 of 200: 9932%
# Rasterizing 95 of 200: 9934%
# Rasterizing 95 of 200: 9937%
# Rasterizing 95 of 200: 9939%
# Rasterizing 95 of 200: 9941%
# Rasterizing 95 of 200: 9944%
# Rasterizing 95 of 200: 9946%
# Rasterizing 95 of 200: 9948%
# Rasterizing 95 of 200: 9951%
# Rasterizing 95 of 200: 9953%
# Rasterizing 95 of 200: 9955%
# Rasterizing 95 of 200: 9958%
# Rasterizing 95 of 200: 9960%
# Rasterizing 95 of 200: 9962%
# Rasterizing 95 of 200: 9965%
# Rasterizing 95 of 200: 9967%
# Rasterizing 95 of 200: 9969%
# Rasterizing 95 of 200: 9972%
# Rasterizing 95 of 200: 9974%
# Rasterizing 95 of 200: 9976%
# Rasterizing 95 of 200: 9979%
# Rasterizing 95 of 200: 9981%
# Rasterizing 95 of 200: 9983%
# Rasterizing 95 of 200: 9986%
# Rasterizing 95 of 200: 9988%
# Rasterizing 95 of 200: 9990%
# Rasterizing 95 of 200: 9993%
# Rasterizing 95 of 200: 9995%
# Rasterizing 95 of 200: 9997%
# Rasterizing 95 of 200: 10000%
# Rasterizing 95 of 200: 10002%
# Rasterizing 95 of 200: 10004%
# Rasterizing 95 of 200: 10006%
# Rasterizing 95 of 200: 10009%
# Rasterizing 95 of 200: 10011%
# Rasterizing 95 of 200: 10013%
# Rasterizing 95 of 200: 10016%
# Rasterizing 95 of 200: 10018%
# Rasterizing 95 of 200: 10020%
# Rasterizing 95 of 200: 10023%
# Rasterizing 95 of 200: 10025%
# Rasterizing 95 of 200: 47%
# Rasterizing 96 of 200: 9775%
# Rasterizing 96 of 200: 9778%
# Rasterizing 96 of 200: 9780%
# Rasterizing 96 of 200: 9782%
# Rasterizing 96 of 200: 9785%
# Rasterizing 96 of 200: 9787%
# Rasterizing 96 of 200: 9790%
# Rasterizing 96 of 200: 9792%
# Rasterizing 96 of 200: 9795%
# Rasterizing 96 of 200: 9797%
# Rasterizing 96 of 200: 9800%
# Rasterizing 96 of 200: 9802%
# Rasterizing 96 of 200: 9804%
# Rasterizing 96 of 200: 9807%
# Rasterizing 96 of 200: 9809%
# Rasterizing 96 of 200: 9812%
# Rasterizing 96 of 200: 9814%
# Rasterizing 96 of 200: 9817%
# Rasterizing 96 of 200: 9819%
# Rasterizing 96 of 200: 9821%
# Rasterizing 96 of 200: 9824%
# Rasterizing 96 of 200: 9826%
# Rasterizing 96 of 200: 9829%
# Rasterizing 96 of 200: 9831%
# Rasterizing 96 of 200: 9834%
# Rasterizing 96 of 200: 9836%
# Rasterizing 96 of 200: 9839%
# Rasterizing 96 of 200: 9841%
# Rasterizing 96 of 200: 9843%
# Rasterizing 96 of 200: 9846%
# Rasterizing 96 of 200: 9848%
# Rasterizing 96 of 200: 9851%
# Rasterizing 96 of 200: 9853%
# Rasterizing 96 of 200: 9856%
# Rasterizing 96 of 200: 9858%
# Rasterizing 96 of 200: 9860%
# Rasterizing 96 of 200: 9863%
# Rasterizing 96 of 200: 9865%
# Rasterizing 96 of 200: 9868%
# Rasterizing 96 of 200: 9870%
# Rasterizing 96 of 200: 9873%
# Rasterizing 96 of 200: 48%
# Rasterizing 97 of 200: 8404%
# Rasterizing 97 of 200: 8406%
# Rasterizing 97 of 200: 8409%
# Rasterizing 97 of 200: 8411%
# Rasterizing 97 of 200: 8413%
# Rasterizing 97 of 200: 8416%
# Rasterizing 97 of 200: 8418%
# Rasterizing 97 of 200: 8420%
# Rasterizing 97 of 200: 8423%
# Rasterizing 97 of 200: 8425%
# Rasterizing 97 of 200: 8427%
# Rasterizing 97 of 200: 8430%
# Rasterizing 97 of 200: 8432%
# Rasterizing 97 of 200: 8434%
# Rasterizing 97 of 200: 8437%
# Rasterizing 97 of 200: 8439%
# Rasterizing 97 of 200: 8441%
# Rasterizing 97 of 200: 8444%
# Rasterizing 97 of 200: 8446%
# Rasterizing 97 of 200: 8448%
# Rasterizing 97 of 200: 8451%
# Rasterizing 97 of 200: 8453%
# Rasterizing 97 of 200: 8455%
# Rasterizing 97 of 200: 8458%
# Rasterizing 97 of 200: 8460%
# Rasterizing 97 of 200: 8462%
# Rasterizing 97 of 200: 8465%
# Rasterizing 97 of 200: 8467%
# Rasterizing 97 of 200: 8469%
# Rasterizing 97 of 200: 8472%
# Rasterizing 97 of 200: 8474%
# Rasterizing 97 of 200: 8476%
# Rasterizing 97 of 200: 8479%
# Rasterizing 97 of 200: 8481%
# Rasterizing 97 of 200: 8483%
# Rasterizing 97 of 200: 8486%
# Rasterizing 97 of 200: 8488%
# Rasterizing 97 of 200: 8490%
# Rasterizing 97 of 200: 8493%
# Rasterizing 97 of 200: 8495%
# Rasterizing 97 of 200: 8497%
# Rasterizing 97 of 200: 8500%
# Rasterizing 97 of 200: 8502%
# Rasterizing 97 of 200: 48%
# Rasterizing 98 of 200: 7986%
# Rasterizing 98 of 200: 7988%
# Rasterizing 98 of 200: 7990%
# Rasterizing 98 of 200: 7993%
# Rasterizing 98 of 200: 7995%
# Rasterizing 98 of 200: 7997%
# Rasterizing 98 of 200: 8000%
# Rasterizing 98 of 200: 8002%
# Rasterizing 98 of 200: 8004%
# Rasterizing 98 of 200: 8006%
# Rasterizing 98 of 200: 8009%
# Rasterizing 98 of 200: 8011%
# Rasterizing 98 of 200: 8013%
# Rasterizing 98 of 200: 8016%
# Rasterizing 98 of 200: 8018%
# Rasterizing 98 of 200: 8020%
# Rasterizing 98 of 200: 8023%
# Rasterizing 98 of 200: 8025%
# Rasterizing 98 of 200: 8027%
# Rasterizing 98 of 200: 8030%
# Rasterizing 98 of 200: 8032%
# Rasterizing 98 of 200: 8034%
# Rasterizing 98 of 200: 8037%
# Rasterizing 98 of 200: 8039%
# Rasterizing 98 of 200: 8041%
# Rasterizing 98 of 200: 8044%
# Rasterizing 98 of 200: 8046%
# Rasterizing 98 of 200: 8048%
# Rasterizing 98 of 200: 8051%
# Rasterizing 98 of 200: 8053%
# Rasterizing 98 of 200: 8055%
# Rasterizing 98 of 200: 8058%
# Rasterizing 98 of 200: 8060%
# Rasterizing 98 of 200: 8062%
# Rasterizing 98 of 200: 8065%
# Rasterizing 98 of 200: 8067%
# Rasterizing 98 of 200: 8069%
# Rasterizing 98 of 200: 8072%
# Rasterizing 98 of 200: 8074%
# Rasterizing 98 of 200: 8076%
# Rasterizing 98 of 200: 8079%
# Rasterizing 98 of 200: 8081%
# Rasterizing 98 of 200: 8083%
# Rasterizing 98 of 200: 49%
# Rasterizing 99 of 200: 5962%
# Rasterizing 99 of 200: 5964%
# Rasterizing 99 of 200: 5966%
# Rasterizing 99 of 200: 5968%
# Rasterizing 99 of 200: 5971%
# Rasterizing 99 of 200: 5973%
# Rasterizing 99 of 200: 5975%
# Rasterizing 99 of 200: 5977%
# Rasterizing 99 of 200: 5980%
# Rasterizing 99 of 200: 5982%
# Rasterizing 99 of 200: 5984%
# Rasterizing 99 of 200: 5986%
# Rasterizing 99 of 200: 5988%
# Rasterizing 99 of 200: 5991%
# Rasterizing 99 of 200: 5993%
# Rasterizing 99 of 200: 5995%
# Rasterizing 99 of 200: 5997%
# Rasterizing 99 of 200: 6000%
# Rasterizing 99 of 200: 6002%
# Rasterizing 99 of 200: 6004%
# Rasterizing 99 of 200: 6006%
# Rasterizing 99 of 200: 6008%
# Rasterizing 99 of 200: 6011%
# Rasterizing 99 of 200: 6013%
# Rasterizing 99 of 200: 6015%
# Rasterizing 99 of 200: 6017%
# Rasterizing 99 of 200: 6020%
# Rasterizing 99 of 200: 6022%
# Rasterizing 99 of 200: 6024%
# Rasterizing 99 of 200: 6026%
# Rasterizing 99 of 200: 6028%
# Rasterizing 99 of 200: 6031%
# Rasterizing 99 of 200: 6033%
# Rasterizing 99 of 200: 6035%
# Rasterizing 99 of 200: 6037%
# Rasterizing 99 of 200: 6040%
# Rasterizing 99 of 200: 6042%
# Rasterizing 99 of 200: 6044%
# Rasterizing 99 of 200: 6046%
# Rasterizing 99 of 200: 6048%
# Rasterizing 99 of 200: 6051%
# Rasterizing 99 of 200: 6053%
# Rasterizing 99 of 200: 6055%
# Rasterizing 99 of 200: 6057%
# Rasterizing 99 of 200: 6060%
# Rasterizing 99 of 200: 49%
# Rasterizing 100 of 200: 4825%
# Rasterizing 100 of 200: 4827%
# Rasterizing 100 of 200: 4830%
# Rasterizing 100 of 200: 4832%
# Rasterizing 100 of 200: 4834%
# Rasterizing 100 of 200: 4837%
# Rasterizing 100 of 200: 4839%
# Rasterizing 100 of 200: 4841%
# Rasterizing 100 of 200: 4844%
# Rasterizing 100 of 200: 4846%
# Rasterizing 100 of 200: 4848%
# Rasterizing 100 of 200: 4851%
# Rasterizing 100 of 200: 4853%
# Rasterizing 100 of 200: 4855%
# Rasterizing 100 of 200: 4858%
# Rasterizing 100 of 200: 4860%
# Rasterizing 100 of 200: 4862%
# Rasterizing 100 of 200: 4865%
# Rasterizing 100 of 200: 4867%
# Rasterizing 100 of 200: 4869%
# Rasterizing 100 of 200: 4872%
# Rasterizing 100 of 200: 4874%
# Rasterizing 100 of 200: 4876%
# Rasterizing 100 of 200: 4879%
# Rasterizing 100 of 200: 4881%
# Rasterizing 100 of 200: 4883%
# Rasterizing 100 of 200: 4886%
# Rasterizing 100 of 200: 4888%
# Rasterizing 100 of 200: 4890%
# Rasterizing 100 of 200: 4893%
# Rasterizing 100 of 200: 4895%
# Rasterizing 100 of 200: 4897%
# Rasterizing 100 of 200: 4900%
# Rasterizing 100 of 200: 4902%
# Rasterizing 100 of 200: 4904%
# Rasterizing 100 of 200: 4906%
# Rasterizing 100 of 200: 4909%
# Rasterizing 100 of 200: 4911%
# Rasterizing 100 of 200: 4913%
# Rasterizing 100 of 200: 4916%
# Rasterizing 100 of 200: 4918%
# Rasterizing 100 of 200: 4920%
# Rasterizing 100 of 200: 4923%
# Rasterizing 100 of 200: 50%
# Rasterizing 101 of 200: 5153%
# Rasterizing 101 of 200: 5155%
# Rasterizing 101 of 200: 5158%
# Rasterizing 101 of 200: 5160%
# Rasterizing 101 of 200: 5162%
# Rasterizing 101 of 200: 5165%
# Rasterizing 101 of 200: 5167%
# Rasterizing 101 of 200: 5169%
# Rasterizing 101 of 200: 5172%
# Rasterizing 101 of 200: 5174%
# Rasterizing 101 of 200: 5176%
# Rasterizing 101 of 200: 5179%
# Rasterizing 101 of 200: 5181%
# Rasterizing 101 of 200: 5183%
# Rasterizing 101 of 200: 5186%
# Rasterizing 101 of 200: 5188%
# Rasterizing 101 of 200: 5190%
# Rasterizing 101 of 200: 5193%
# Rasterizing 101 of 200: 5195%
# Rasterizing 101 of 200: 5197%
# Rasterizing 101 of 200: 5200%
# Rasterizing 101 of 200: 5202%
# Rasterizing 101 of 200: 5204%
# Rasterizing 101 of 200: 5206%
# Rasterizing 101 of 200: 5209%
# Rasterizing 101 of 200: 5211%
# Rasterizing 101 of 200: 5213%
# Rasterizing 101 of 200: 5216%
# Rasterizing 101 of 200: 5218%
# Rasterizing 101 of 200: 5220%
# Rasterizing 101 of 200: 5223%
# Rasterizing 101 of 200: 5225%
# Rasterizing 101 of 200: 5227%
# Rasterizing 101 of 200: 5230%
# Rasterizing 101 of 200: 5232%
# Rasterizing 101 of 200: 5234%
# Rasterizing 101 of 200: 5237%
# Rasterizing 101 of 200: 5239%
# Rasterizing 101 of 200: 5241%
# Rasterizing 101 of 200: 5244%
# Rasterizing 101 of 200: 5246%
# Rasterizing 101 of 200: 5248%
# Rasterizing 101 of 200: 5251%
# Rasterizing 101 of 200: 50%
# Rasterizing 102 of 200: 51%
# Rasterizing 104 of 200: 52%
# Rasterizing 106 of 200: 53%
# Rasterizing 108 of 200: 54%
# Rasterizing 110 of 200: 55%
# Rasterizing 112 of 200: 56%
# Rasterizing 114 of 200: 57%
# Rasterizing 116 of 200: 58%
# Rasterizing 118 of 200: 59%
# Rasterizing 120 of 200: 60%
# Rasterizing 122 of 200: 61%
# Rasterizing 124 of 200: 62%
# Rasterizing 126 of 200: 63%
# Rasterizing 128 of 200: 64%
# Rasterizing 130 of 200: 65%
# Rasterizing 132 of 200: 66%
# Rasterizing 134 of 200: 67%
# Rasterizing 136 of 200: 68%
# Rasterizing 138 of 200: 69%
# Rasterizing 140 of 200: 70%
# Rasterizing 142 of 200: 71%
# Rasterizing 144 of 200: 72%
# Rasterizing 146 of 200: 73%
# Rasterizing 148 of 200: 74%
# Rasterizing 150 of 200: 75%
# Rasterizing 152 of 200: 76%
# Rasterizing 154 of 200: 77%
# Rasterizing 156 of 200: 78%
# Rasterizing 158 of 200: 79%
# Rasterizing 160 of 200: 80%
# Rasterizing 162 of 200: 81%
# Rasterizing 164 of 200: 82%
# Rasterizing 166 of 200: 83%
# Rasterizing 168 of 200: 84%
# Rasterizing 170 of 200: 85%
# Rasterizing 172 of 200: 86%
# Rasterizing 174 of 200: 87%
# Rasterizing 176 of 200: 88%
# Rasterizing 178 of 200: 89%
# Rasterizing 180 of 200: 90%
# Rasterizing 182 of 200: 91%
# Rasterizing 184 of 200: 92%
# Rasterizing 186 of 200: 93%
# Rasterizing 188 of 200: 94%
# Rasterizing 190 of 200: 95%
# Rasterizing 192 of 200: 96%
# Rasterizing 194 of 200: 97%
# Rasterizing 196 of 200: 98%
# Rasterizing 198 of 200: 11614%
# Rasterizing 198 of 200: 11617%
# Rasterizing 198 of 200: 11619%
# Rasterizing 198 of 200: 11621%
# Rasterizing 198 of 200: 11624%
# Rasterizing 198 of 200: 11626%
# Rasterizing 198 of 200: 11629%
# Rasterizing 198 of 200: 11631%
# Rasterizing 198 of 200: 11634%
# Rasterizing 198 of 200: 11636%
# Rasterizing 198 of 200: 11639%
# Rasterizing 198 of 200: 11641%
# Rasterizing 198 of 200: 11643%
# Rasterizing 198 of 200: 11646%
# Rasterizing 198 of 200: 11648%
# Rasterizing 198 of 200: 11651%
# Rasterizing 198 of 200: 11653%
# Rasterizing 198 of 200: 11656%
# Rasterizing 198 of 200: 11658%
# Rasterizing 198 of 200: 11660%
# Rasterizing 198 of 200: 11663%
# Rasterizing 198 of 200: 11665%
# Rasterizing 198 of 200: 11668%
# Rasterizing 198 of 200: 11670%
# Rasterizing 198 of 200: 11673%
# Rasterizing 198 of 200: 11675%
# Rasterizing 198 of 200: 11678%
# Rasterizing 198 of 200: 11680%
# Rasterizing 198 of 200: 11682%
# Rasterizing 198 of 200: 11685%
# Rasterizing 198 of 200: 11687%
# Rasterizing 198 of 200: 11690%
# Rasterizing 198 of 200: 11692%
# Rasterizing 198 of 200: 11695%
# Rasterizing 198 of 200: 11697%
# Rasterizing 198 of 200: 11700%
# Rasterizing 198 of 200: 11702%
# Rasterizing 198 of 200: 11704%
# Rasterizing 198 of 200: 11707%
# Rasterizing 198 of 200: 11709%
# Rasterizing 198 of 200: 11712%
# Rasterizing 198 of 200: 99%
# Rasterizing 199 of 200: 1208%
# Rasterizing 199 of 200: 1210%
# Rasterizing 199 of 200: 1213%
# Rasterizing 199 of 200: 1216%
# Rasterizing 199 of 200: 1218%
# Rasterizing 199 of 200: 1221%
# Rasterizing 199 of 200: 1224%
# Rasterizing 199 of 200: 1227%
# Rasterizing 199 of 200: 1229%
# Rasterizing 199 of 200: 1232%
# Rasterizing 199 of 200: 1235%
# Rasterizing 199 of 200: 1237%
# Rasterizing 199 of 200: 1240%
# Rasterizing 199 of 200: 1243%
# Rasterizing 199 of 200: 1245%
# Rasterizing 199 of 200: 1248%
# Rasterizing 199 of 200: 1251%
# Rasterizing 199 of 200: 1254%
# Rasterizing 199 of 200: 1256%
# Rasterizing 199 of 200: 1259%
# Rasterizing 199 of 200: 1262%
# Rasterizing 199 of 200: 1264%
# Rasterizing 199 of 200: 1267%
# Rasterizing 199 of 200: 1270%
# Rasterizing 199 of 200: 1272%
# Rasterizing 199 of 200: 1275%
# Rasterizing 199 of 200: 1278%
# Rasterizing 199 of 200: 1281%
# Rasterizing 199 of 200: 1283%
# Rasterizing 199 of 200: 1286%
# Rasterizing 199 of 200: 1289%
# Rasterizing 199 of 200: 1291%
# Rasterizing 199 of 200: 1294%
# Rasterizing 199 of 200: 1297%
# Rasterizing 199 of 200: 1300%
# Rasterizing 199 of 200: 1302%
# Rasterizing 199 of 200: 1305%
# Rasterizing 199 of 200: 99%
# Rasterizing 200 of 200: 3868%
# Rasterizing 200 of 200: 3870%
# Rasterizing 200 of 200: 3873%
# Rasterizing 200 of 200: 3875%
# Rasterizing 200 of 200: 3878%
# Rasterizing 200 of 200: 3880%
# Rasterizing 200 of 200: 3882%
# Rasterizing 200 of 200: 3885%
# Rasterizing 200 of 200: 3887%
# Rasterizing 200 of 200: 3890%
# Rasterizing 200 of 200: 3892%
# Rasterizing 200 of 200: 3895%
# Rasterizing 200 of 200: 3897%
# Rasterizing 200 of 200: 3900%
# Rasterizing 200 of 200: 3902%
# Rasterizing 200 of 200: 3904%
# Rasterizing 200 of 200: 3907%
# Rasterizing 200 of 200: 3909%
# Rasterizing 200 of 200: 3912%
# Rasterizing 200 of 200: 3914%
# Rasterizing 200 of 200: 3917%
# Rasterizing 200 of 200: 3919%
# Rasterizing 200 of 200: 3921%
# Rasterizing 200 of 200: 3924%
# Rasterizing 200 of 200: 3926%
# Rasterizing 200 of 200: 3929%
# Rasterizing 200 of 200: 3931%
# Rasterizing 200 of 200: 3934%
# Rasterizing 200 of 200: 3936%
# Rasterizing 200 of 200: 3939%
# Rasterizing 200 of 200: 3941%
# Rasterizing 200 of 200: 3943%
# Rasterizing 200 of 200: 3946%
# Rasterizing 200 of 200: 3948%
# Rasterizing 200 of 200: 3951%
# Rasterizing 200 of 200: 3953%
# Rasterizing 200 of 200: 3956%
# Rasterizing 200 of 200: 3958%
# Rasterizing 200 of 200: 3960%
# Rasterizing 200 of 200: 3963%
# Rasterizing 200 of 200: 3965%
# Rasterizing 200 of 200: 100%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.704s
# ./whitebox_tools --run="VectorPolygonsToRaster" --input='/workspace/data/charcoal_kilns/charcoal_kilns_buffer.shp' --field=class --output='/workspace/data/label_tiles/18E028_69100_4500_25.tif' --base='/workspace/data/selected_dems/18E028_69100_4500_25.tif'
#
# *************************************
# * Welcome to VectorPolygonsToRaster *
# * Powered by WhiteboxTools          *
# * www.whiteboxgeo.com               *
# *************************************
# Reading data...
# Reading attributes: 0%
# Reading attributes: 1%
# Reading attributes: 2%
# Reading attributes: 3%
# Reading attributes: 4%
# Reading attributes: 5%
# Reading attributes: 6%
# Reading attributes: 7%
# Reading attributes: 8%
# Reading attributes: 9%
# Reading attributes: 10%
# Reading attributes: 11%
# Reading attributes: 12%
# Reading attributes: 13%
# Reading attributes: 14%
# Reading attributes: 15%
# Reading attributes: 16%
# Reading attributes: 17%
# Reading attributes: 18%
# Reading attributes: 19%
# Reading attributes: 20%
# Reading attributes: 21%
# Reading attributes: 22%
# Reading attributes: 23%
# Reading attributes: 24%
# Reading attributes: 25%
# Reading attributes: 26%
# Reading attributes: 27%
# Reading attributes: 28%
# Reading attributes: 29%
# Reading attributes: 30%
# Reading attributes: 31%
# Reading attributes: 32%
# Reading attributes: 33%
# Reading attributes: 34%
# Reading attributes: 35%
# Reading attributes: 36%
# Reading attributes: 37%
# Reading attributes: 38%
# Reading attributes: 39%
# Reading attributes: 40%
# Reading attributes: 41%
# Reading attributes: 42%
# Reading attributes: 43%
# Reading attributes: 44%
# Reading attributes: 45%
# Reading attributes: 46%
# Reading attributes: 47%
# Reading attributes: 48%
# Reading attributes: 49%
# Reading attributes: 50%
# Reading attributes: 51%
# Reading attributes: 52%
# Reading attributes: 53%
# Reading attributes: 54%
# Reading attributes: 55%
# Reading attributes: 56%
# Reading attributes: 57%
# Reading attributes: 58%
# Reading attributes: 59%
# Reading attributes: 60%
# Reading attributes: 61%
# Reading attributes: 62%
# Reading attributes: 63%
# Reading attributes: 64%
# Reading attributes: 65%
# Reading attributes: 66%
# Reading attributes: 67%
# Reading attributes: 68%
# Reading attributes: 69%
# Reading attributes: 70%
# Reading attributes: 71%
# Reading attributes: 72%
# Reading attributes: 73%
# Reading attributes: 74%
# Reading attributes: 75%
# ...
# Rasterizing 85 of 200: 5381%
# Rasterizing 85 of 200: 5383%
# Rasterizing 85 of 200: 5386%
# Rasterizing 85 of 200: 5388%
# Rasterizing 85 of 200: 5390%
# Rasterizing 85 of 200: 5393%
# Rasterizing 85 of 200: 5395%
# Rasterizing 85 of 200: 5397%
# Rasterizing 85 of 200: 5400%
# Rasterizing 85 of 200: 5402%
# Rasterizing 85 of 200: 5404%
# Rasterizing 85 of 200: 5406%
# Rasterizing 85 of 200: 5409%
# Rasterizing 85 of 200: 5411%
# Rasterizing 85 of 200: 5413%
# Rasterizing 85 of 200: 5416%
# Rasterizing 85 of 200: 5418%
# Rasterizing 85 of 200: 5420%
# Rasterizing 85 of 200: 5423%
# Rasterizing 85 of 200: 5425%
# Rasterizing 85 of 200: 5427%
# Rasterizing 85 of 200: 5430%
# Rasterizing 85 of 200: 5432%
# Rasterizing 85 of 200: 5434%
# Rasterizing 85 of 200: 5437%
# Rasterizing 85 of 200: 5439%
# Rasterizing 85 of 200: 5441%
# Rasterizing 85 of 200: 42%
# Rasterizing 86 of 200: 1744%
# Rasterizing 86 of 200: 1746%
# Rasterizing 86 of 200: 1748%
# Rasterizing 86 of 200: 1751%
# Rasterizing 86 of 200: 1753%
# Rasterizing 86 of 200: 1755%
# Rasterizing 86 of 200: 1758%
# Rasterizing 86 of 200: 1760%
# Rasterizing 86 of 200: 1762%
# Rasterizing 86 of 200: 1765%
# Rasterizing 86 of 200: 1767%
# Rasterizing 86 of 200: 1769%
# Rasterizing 86 of 200: 1772%
# Rasterizing 86 of 200: 1774%
# Rasterizing 86 of 200: 1776%
# Rasterizing 86 of 200: 1779%
# Rasterizing 86 of 200: 1781%
# Rasterizing 86 of 200: 1783%
# Rasterizing 86 of 200: 1786%
# Rasterizing 86 of 200: 1788%
# Rasterizing 86 of 200: 1790%
# Rasterizing 86 of 200: 1793%
# Rasterizing 86 of 200: 1795%
# Rasterizing 86 of 200: 1797%
# Rasterizing 86 of 200: 1800%
# Rasterizing 86 of 200: 1802%
# Rasterizing 86 of 200: 1804%
# Rasterizing 86 of 200: 1806%
# Rasterizing 86 of 200: 1809%
# Rasterizing 86 of 200: 1811%
# Rasterizing 86 of 200: 1813%
# Rasterizing 86 of 200: 1816%
# Rasterizing 86 of 200: 1818%
# Rasterizing 86 of 200: 1820%
# Rasterizing 86 of 200: 1823%
# Rasterizing 86 of 200: 1825%
# Rasterizing 86 of 200: 1827%
# Rasterizing 86 of 200: 1830%
# Rasterizing 86 of 200: 1832%
# Rasterizing 86 of 200: 1834%
# Rasterizing 86 of 200: 1837%
# Rasterizing 86 of 200: 1839%
# Rasterizing 86 of 200: 1841%
# Rasterizing 86 of 200: 43%
# Rasterizing 87 of 200: 806%
# Rasterizing 87 of 200: 809%
# Rasterizing 87 of 200: 811%
# Rasterizing 87 of 200: 813%
# Rasterizing 87 of 200: 816%
# Rasterizing 87 of 200: 818%
# Rasterizing 87 of 200: 820%
# Rasterizing 87 of 200: 823%
# Rasterizing 87 of 200: 825%
# Rasterizing 87 of 200: 827%
# Rasterizing 87 of 200: 830%
# Rasterizing 87 of 200: 832%
# Rasterizing 87 of 200: 834%
# Rasterizing 87 of 200: 837%
# Rasterizing 87 of 200: 839%
# Rasterizing 87 of 200: 841%
# Rasterizing 87 of 200: 844%
# Rasterizing 87 of 200: 846%
# Rasterizing 87 of 200: 848%
# Rasterizing 87 of 200: 851%
# Rasterizing 87 of 200: 853%
# Rasterizing 87 of 200: 855%
# Rasterizing 87 of 200: 858%
# Rasterizing 87 of 200: 860%
# Rasterizing 87 of 200: 862%
# Rasterizing 87 of 200: 865%
# Rasterizing 87 of 200: 867%
# Rasterizing 87 of 200: 869%
# Rasterizing 87 of 200: 872%
# Rasterizing 87 of 200: 874%
# Rasterizing 87 of 200: 876%
# Rasterizing 87 of 200: 879%
# Rasterizing 87 of 200: 881%
# Rasterizing 87 of 200: 883%
# Rasterizing 87 of 200: 886%
# Rasterizing 87 of 200: 888%
# Rasterizing 87 of 200: 890%
# Rasterizing 87 of 200: 893%
# Rasterizing 87 of 200: 895%
# Rasterizing 87 of 200: 897%
# Rasterizing 87 of 200: 900%
# Rasterizing 87 of 200: 902%
# Rasterizing 87 of 200: 904%
# Rasterizing 87 of 200: 43%
# Rasterizing 88 of 200: 146%
# Rasterizing 88 of 200: 148%
# Rasterizing 88 of 200: 151%
# Rasterizing 88 of 200: 153%
# Rasterizing 88 of 200: 155%
# Rasterizing 88 of 200: 158%
# Rasterizing 88 of 200: 160%
# Rasterizing 88 of 200: 162%
# Rasterizing 88 of 200: 165%
# Rasterizing 88 of 200: 167%
# Rasterizing 88 of 200: 169%
# Rasterizing 88 of 200: 172%
# Rasterizing 88 of 200: 174%
# Rasterizing 88 of 200: 176%
# Rasterizing 88 of 200: 179%
# Rasterizing 88 of 200: 181%
# Rasterizing 88 of 200: 183%
# Rasterizing 88 of 200: 186%
# Rasterizing 88 of 200: 188%
# Rasterizing 88 of 200: 190%
# Rasterizing 88 of 200: 193%
# Rasterizing 88 of 200: 195%
# Rasterizing 88 of 200: 197%
# Rasterizing 88 of 200: 200%
# Rasterizing 88 of 200: 202%
# Rasterizing 88 of 200: 204%
# Rasterizing 88 of 200: 206%
# Rasterizing 88 of 200: 209%
# Rasterizing 88 of 200: 211%
# Rasterizing 88 of 200: 213%
# Rasterizing 88 of 200: 216%
# Rasterizing 88 of 200: 218%
# Rasterizing 88 of 200: 220%
# Rasterizing 88 of 200: 223%
# Rasterizing 88 of 200: 225%
# Rasterizing 88 of 200: 227%
# Rasterizing 88 of 200: 230%
# Rasterizing 88 of 200: 232%
# Rasterizing 88 of 200: 234%
# Rasterizing 88 of 200: 237%
# Rasterizing 88 of 200: 239%
# Rasterizing 88 of 200: 241%
# Rasterizing 88 of 200: 244%
# Rasterizing 88 of 200: 44%
# Rasterizing 90 of 200: 45%
# Rasterizing 92 of 200: 46%
# Rasterizing 94 of 200: 47%
# Rasterizing 96 of 200: 48%
# Rasterizing 98 of 200: 49%
# Rasterizing 100 of 200: 50%
# Rasterizing 102 of 200: 51%
# Rasterizing 104 of 200: 52%
# Rasterizing 106 of 200: 53%
# Rasterizing 108 of 200: 54%
# Rasterizing 110 of 200: 55%
# Rasterizing 112 of 200: 56%
# Rasterizing 114 of 200: 57%
# Rasterizing 116 of 200: 58%
# Rasterizing 118 of 200: 59%
# Rasterizing 120 of 200: 60%
# Rasterizing 122 of 200: 61%
# Rasterizing 124 of 200: 62%
# Rasterizing 126 of 200: 63%
# Rasterizing 128 of 200: 64%
# Rasterizing 130 of 200: 65%
# Rasterizing 132 of 200: 66%
# Rasterizing 134 of 200: 67%
# Rasterizing 136 of 200: 68%
# Rasterizing 138 of 200: 69%
# Rasterizing 140 of 200: 70%
# Rasterizing 142 of 200: 71%
# Rasterizing 144 of 200: 72%
# Rasterizing 146 of 200: 73%
# Rasterizing 148 of 200: 74%
# Rasterizing 150 of 200: 75%
# Rasterizing 152 of 200: 76%
# Rasterizing 154 of 200: 77%
# Rasterizing 156 of 200: 78%
# Rasterizing 158 of 200: 79%
# Rasterizing 160 of 200: 80%
# Rasterizing 162 of 200: 81%
# Rasterizing 164 of 200: 82%
# Rasterizing 166 of 200: 83%
# Rasterizing 168 of 200: 84%
# Rasterizing 170 of 200: 85%
# Rasterizing 172 of 200: 86%
# Rasterizing 174 of 200: 87%
# Rasterizing 176 of 200: 88%
# Rasterizing 177 of 200: 9322%
# Rasterizing 177 of 200: 9324%
# Rasterizing 177 of 200: 9326%
# Rasterizing 177 of 200: 9328%
# Rasterizing 177 of 200: 9330%
# Rasterizing 177 of 200: 9332%
# Rasterizing 177 of 200: 9334%
# Rasterizing 177 of 200: 9336%
# Rasterizing 177 of 200: 9338%
# Rasterizing 177 of 200: 9340%
# Rasterizing 177 of 200: 9342%
# Rasterizing 177 of 200: 9344%
# Rasterizing 177 of 200: 9346%
# Rasterizing 177 of 200: 9348%
# Rasterizing 177 of 200: 9351%
# Rasterizing 177 of 200: 9353%
# Rasterizing 177 of 200: 9355%
# Rasterizing 177 of 200: 9357%
# Rasterizing 177 of 200: 9359%
# Rasterizing 177 of 200: 9361%
# Rasterizing 177 of 200: 9363%
# Rasterizing 177 of 200: 9365%
# Rasterizing 177 of 200: 9367%
# Rasterizing 177 of 200: 9369%
# Rasterizing 177 of 200: 9371%
# Rasterizing 177 of 200: 9373%
# Rasterizing 177 of 200: 9375%
# Rasterizing 177 of 200: 9377%
# Rasterizing 177 of 200: 9379%
# Rasterizing 177 of 200: 9381%
# Rasterizing 177 of 200: 9383%
# Rasterizing 177 of 200: 9385%
# Rasterizing 177 of 200: 9387%
# Rasterizing 177 of 200: 9389%
# Rasterizing 177 of 200: 9391%
# Rasterizing 177 of 200: 9393%
# Rasterizing 177 of 200: 9395%
# Rasterizing 177 of 200: 9397%
# Rasterizing 177 of 200: 9400%
# Rasterizing 177 of 200: 9402%
# Rasterizing 177 of 200: 9404%
# Rasterizing 177 of 200: 9406%
# Rasterizing 177 of 200: 9408%
# Rasterizing 177 of 200: 9410%
# Rasterizing 177 of 200: 9412%
# Rasterizing 177 of 200: 9414%
# Rasterizing 177 of 200: 9416%
# Rasterizing 177 of 200: 9418%
# Rasterizing 177 of 200: 9420%
# Rasterizing 177 of 200: 88%
# Rasterizing 178 of 200: 10606%
# Rasterizing 178 of 200: 10608%
# Rasterizing 178 of 200: 10611%
# Rasterizing 178 of 200: 10613%
# Rasterizing 178 of 200: 10615%
# Rasterizing 178 of 200: 10617%
# Rasterizing 178 of 200: 10620%
# Rasterizing 178 of 200: 10622%
# Rasterizing 178 of 200: 10624%
# Rasterizing 178 of 200: 10626%
# Rasterizing 178 of 200: 10628%
# Rasterizing 178 of 200: 10631%
# Rasterizing 178 of 200: 10633%
# Rasterizing 178 of 200: 10635%
# Rasterizing 178 of 200: 10637%
# Rasterizing 178 of 200: 10640%
# Rasterizing 178 of 200: 10642%
# Rasterizing 178 of 200: 10644%
# Rasterizing 178 of 200: 10646%
# Rasterizing 178 of 200: 10648%
# Rasterizing 178 of 200: 10651%
# Rasterizing 178 of 200: 10653%
# Rasterizing 178 of 200: 10655%
# Rasterizing 178 of 200: 10657%
# Rasterizing 178 of 200: 10660%
# Rasterizing 178 of 200: 10662%
# Rasterizing 178 of 200: 10664%
# Rasterizing 178 of 200: 10666%
# Rasterizing 178 of 200: 10668%
# Rasterizing 178 of 200: 10671%
# Rasterizing 178 of 200: 10673%
# Rasterizing 178 of 200: 10675%
# Rasterizing 178 of 200: 10677%
# Rasterizing 178 of 200: 10680%
# Rasterizing 178 of 200: 10682%
# Rasterizing 178 of 200: 10684%
# Rasterizing 178 of 200: 10686%
# Rasterizing 178 of 200: 10688%
# Rasterizing 178 of 200: 10691%
# Rasterizing 178 of 200: 10693%
# Rasterizing 178 of 200: 10695%
# Rasterizing 178 of 200: 10697%
# Rasterizing 178 of 200: 10700%
# Rasterizing 178 of 200: 10702%
# Rasterizing 178 of 200: 10704%
# Rasterizing 178 of 200: 89%
# Rasterizing 179 of 200: 10493%
# Rasterizing 179 of 200: 10495%
# Rasterizing 179 of 200: 10497%
# Rasterizing 179 of 200: 10500%
# Rasterizing 179 of 200: 10502%
# Rasterizing 179 of 200: 10504%
# Rasterizing 179 of 200: 10506%
# Rasterizing 179 of 200: 10508%
# Rasterizing 179 of 200: 10511%
# Rasterizing 179 of 200: 10513%
# Rasterizing 179 of 200: 10515%
# Rasterizing 179 of 200: 10517%
# Rasterizing 179 of 200: 10520%
# Rasterizing 179 of 200: 10522%
# Rasterizing 179 of 200: 10524%
# Rasterizing 179 of 200: 10526%
# Rasterizing 179 of 200: 10528%
# Rasterizing 179 of 200: 10531%
# Rasterizing 179 of 200: 10533%
# Rasterizing 179 of 200: 10535%
# Rasterizing 179 of 200: 10537%
# Rasterizing 179 of 200: 10540%
# Rasterizing 179 of 200: 10542%
# Rasterizing 179 of 200: 10544%
# Rasterizing 179 of 200: 10546%
# Rasterizing 179 of 200: 10548%
# Rasterizing 179 of 200: 10551%
# Rasterizing 179 of 200: 10553%
# Rasterizing 179 of 200: 10555%
# Rasterizing 179 of 200: 10557%
# Rasterizing 179 of 200: 10560%
# Rasterizing 179 of 200: 10562%
# Rasterizing 179 of 200: 10564%
# Rasterizing 179 of 200: 10566%
# Rasterizing 179 of 200: 10568%
# Rasterizing 179 of 200: 10571%
# Rasterizing 179 of 200: 10573%
# Rasterizing 179 of 200: 10575%
# Rasterizing 179 of 200: 10577%
# Rasterizing 179 of 200: 10580%
# Rasterizing 179 of 200: 10582%
# Rasterizing 179 of 200: 10584%
# Rasterizing 179 of 200: 10586%
# Rasterizing 179 of 200: 10588%
# Rasterizing 179 of 200: 10591%
# Rasterizing 179 of 200: 89%
# Rasterizing 180 of 200: 9953%
# Rasterizing 180 of 200: 9955%
# Rasterizing 180 of 200: 9957%
# Rasterizing 180 of 200: 9960%
# Rasterizing 180 of 200: 9962%
# Rasterizing 180 of 200: 9964%
# Rasterizing 180 of 200: 9966%
# Rasterizing 180 of 200: 9968%
# Rasterizing 180 of 200: 9971%
# Rasterizing 180 of 200: 9973%
# Rasterizing 180 of 200: 9975%
# Rasterizing 180 of 200: 9977%
# Rasterizing 180 of 200: 9980%
# Rasterizing 180 of 200: 9982%
# Rasterizing 180 of 200: 9984%
# Rasterizing 180 of 200: 9986%
# Rasterizing 180 of 200: 9988%
# Rasterizing 180 of 200: 9991%
# Rasterizing 180 of 200: 9993%
# Rasterizing 180 of 200: 9995%
# Rasterizing 180 of 200: 9997%
# Rasterizing 180 of 200: 10000%
# Rasterizing 180 of 200: 10002%
# Rasterizing 180 of 200: 10004%
# Rasterizing 180 of 200: 10006%
# Rasterizing 180 of 200: 10008%
# Rasterizing 180 of 200: 10011%
# Rasterizing 180 of 200: 10013%
# Rasterizing 180 of 200: 10015%
# Rasterizing 180 of 200: 10017%
# Rasterizing 180 of 200: 10020%
# Rasterizing 180 of 200: 10022%
# Rasterizing 180 of 200: 10024%
# Rasterizing 180 of 200: 10026%
# Rasterizing 180 of 200: 10028%
# Rasterizing 180 of 200: 10031%
# Rasterizing 180 of 200: 10033%
# Rasterizing 180 of 200: 10035%
# Rasterizing 180 of 200: 10037%
# Rasterizing 180 of 200: 10040%
# Rasterizing 180 of 200: 10042%
# Rasterizing 180 of 200: 10044%
# Rasterizing 180 of 200: 10046%
# Rasterizing 180 of 200: 10048%
# Rasterizing 180 of 200: 10051%
# Rasterizing 180 of 200: 90%
# Rasterizing 181 of 200: 9326%
# Rasterizing 181 of 200: 9328%
# Rasterizing 181 of 200: 9331%
# Rasterizing 181 of 200: 9333%
# Rasterizing 181 of 200: 9335%
# Rasterizing 181 of 200: 9337%
# Rasterizing 181 of 200: 9340%
# Rasterizing 181 of 200: 9342%
# Rasterizing 181 of 200: 9344%
# Rasterizing 181 of 200: 9346%
# Rasterizing 181 of 200: 9348%
# Rasterizing 181 of 200: 9351%
# Rasterizing 181 of 200: 9353%
# Rasterizing 181 of 200: 9355%
# Rasterizing 181 of 200: 9357%
# Rasterizing 181 of 200: 9360%
# Rasterizing 181 of 200: 9362%
# Rasterizing 181 of 200: 9364%
# Rasterizing 181 of 200: 9366%
# Rasterizing 181 of 200: 9368%
# Rasterizing 181 of 200: 9371%
# Rasterizing 181 of 200: 9373%
# Rasterizing 181 of 200: 9375%
# Rasterizing 181 of 200: 9377%
# Rasterizing 181 of 200: 9380%
# Rasterizing 181 of 200: 9382%
# Rasterizing 181 of 200: 9384%
# Rasterizing 181 of 200: 9386%
# Rasterizing 181 of 200: 9388%
# Rasterizing 181 of 200: 9391%
# Rasterizing 181 of 200: 9393%
# Rasterizing 181 of 200: 9395%
# Rasterizing 181 of 200: 9397%
# Rasterizing 181 of 200: 9400%
# Rasterizing 181 of 200: 9402%
# Rasterizing 181 of 200: 9404%
# Rasterizing 181 of 200: 9406%
# Rasterizing 181 of 200: 9408%
# Rasterizing 181 of 200: 9411%
# Rasterizing 181 of 200: 9413%
# Rasterizing 181 of 200: 9415%
# Rasterizing 181 of 200: 9417%
# Rasterizing 181 of 200: 9420%
# Rasterizing 181 of 200: 9422%
# Rasterizing 181 of 200: 9424%
# Rasterizing 181 of 200: 90%
# Rasterizing 182 of 200: 9217%
# Rasterizing 182 of 200: 9220%
# Rasterizing 182 of 200: 9222%
# Rasterizing 182 of 200: 9224%
# Rasterizing 182 of 200: 9226%
# Rasterizing 182 of 200: 9228%
# Rasterizing 182 of 200: 9231%
# Rasterizing 182 of 200: 9233%
# Rasterizing 182 of 200: 9235%
# Rasterizing 182 of 200: 9237%
# Rasterizing 182 of 200: 9240%
# Rasterizing 182 of 200: 9242%
# Rasterizing 182 of 200: 9244%
# Rasterizing 182 of 200: 9246%
# Rasterizing 182 of 200: 9248%
# Rasterizing 182 of 200: 9251%
# Rasterizing 182 of 200: 9253%
# Rasterizing 182 of 200: 9255%
# Rasterizing 182 of 200: 9257%
# Rasterizing 182 of 200: 9260%
# Rasterizing 182 of 200: 9262%
# Rasterizing 182 of 200: 9264%
# Rasterizing 182 of 200: 9266%
# Rasterizing 182 of 200: 9268%
# Rasterizing 182 of 200: 9271%
# Rasterizing 182 of 200: 9273%
# Rasterizing 182 of 200: 9275%
# Rasterizing 182 of 200: 9277%
# Rasterizing 182 of 200: 9280%
# Rasterizing 182 of 200: 9282%
# Rasterizing 182 of 200: 9284%
# Rasterizing 182 of 200: 9286%
# Rasterizing 182 of 200: 9288%
# Rasterizing 182 of 200: 9291%
# Rasterizing 182 of 200: 9293%
# Rasterizing 182 of 200: 9295%
# Rasterizing 182 of 200: 9297%
# Rasterizing 182 of 200: 9300%
# Rasterizing 182 of 200: 9302%
# Rasterizing 182 of 200: 9304%
# Rasterizing 182 of 200: 9306%
# Rasterizing 182 of 200: 9308%
# Rasterizing 182 of 200: 9311%
# Rasterizing 182 of 200: 9313%
# Rasterizing 182 of 200: 9315%
# Rasterizing 182 of 200: 91%
# Rasterizing 183 of 200: 9333%
# Rasterizing 183 of 200: 9335%
# Rasterizing 183 of 200: 9337%
# Rasterizing 183 of 200: 9340%
# Rasterizing 183 of 200: 9342%
# Rasterizing 183 of 200: 9344%
# Rasterizing 183 of 200: 9346%
# Rasterizing 183 of 200: 9348%
# Rasterizing 183 of 200: 9351%
# Rasterizing 183 of 200: 9353%
# Rasterizing 183 of 200: 9355%
# Rasterizing 183 of 200: 9357%
# Rasterizing 183 of 200: 9360%
# Rasterizing 183 of 200: 9362%
# Rasterizing 183 of 200: 9364%
# Rasterizing 183 of 200: 9366%
# Rasterizing 183 of 200: 9368%
# Rasterizing 183 of 200: 9371%
# Rasterizing 183 of 200: 9373%
# Rasterizing 183 of 200: 9375%
# Rasterizing 183 of 200: 9377%
# Rasterizing 183 of 200: 9380%
# Rasterizing 183 of 200: 9382%
# Rasterizing 183 of 200: 9384%
# Rasterizing 183 of 200: 9386%
# Rasterizing 183 of 200: 9388%
# Rasterizing 183 of 200: 9391%
# Rasterizing 183 of 200: 9393%
# Rasterizing 183 of 200: 9395%
# Rasterizing 183 of 200: 9397%
# Rasterizing 183 of 200: 9400%
# Rasterizing 183 of 200: 9402%
# Rasterizing 183 of 200: 9404%
# Rasterizing 183 of 200: 9406%
# Rasterizing 183 of 200: 9408%
# Rasterizing 183 of 200: 9411%
# Rasterizing 183 of 200: 9413%
# Rasterizing 183 of 200: 9415%
# Rasterizing 183 of 200: 9417%
# Rasterizing 183 of 200: 9420%
# Rasterizing 183 of 200: 9422%
# Rasterizing 183 of 200: 9424%
# Rasterizing 183 of 200: 9426%
# Rasterizing 183 of 200: 9428%
# Rasterizing 183 of 200: 9431%
# Rasterizing 183 of 200: 91%
# Rasterizing 184 of 200: 92%
# Rasterizing 186 of 200: 93%
# Rasterizing 188 of 200: 94%
# Rasterizing 190 of 200: 95%
# Rasterizing 192 of 200: 96%
# Rasterizing 194 of 200: 97%
# Rasterizing 196 of 200: 98%
# Rasterizing 198 of 200: 99%
# Rasterizing 200 of 200: 100%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.712s

# %% [markdown]
# ## Create topographical indices from laser data

# %%
# !python /workspace/code/Topographical_indicies.py /workspace/data/selected_dems/ /workspace/data/topographical_indices/hillshade/ /workspace/data/topographical_indices/slope/ /workspace/data/topographical_indices/hpmf/

# %%
# !python /workspace/code/normalize_indices.py /workspace/data/topographical_indices/hillshade/ /workspace/data/topographical_indices_normalized/hillshade/ /workspace/data/topographical_indices/slope/ /workspace/data/topographical_indices_normalized/slope/ /workspace/data/topographical_indices/hpmf/ /workspace/data/topographical_indices_normalized/hpmf/
# Out:
# normalized hillshade /workspace/data/topographical_indices/hillshade/18E028_69000_4550_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/18E028_69025_4500_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/18E028_69050_4500_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/18E028_69050_4525_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/18E028_69075_4500_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/18E028_69075_4525_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/18E028_69100_4500_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/18E028_69100_4525_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/20E018_68750_4750_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/20E018_68750_4775_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/20E018_68750_4800_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/20E018_68775_4750_25.tif
# normalized hillshade /workspace/data/topographical_indices/hillshade/20E018_68775_4775_25.tif
# normalized slope /workspace/data/topographical_indices/slope/18E028_69000_4550_25.tif
# normalized slope /workspace/data/topographical_indices/slope/18E028_69025_4500_25.tif
# normalized slope /workspace/data/topographical_indices/slope/18E028_69050_4500_25.tif
# normalized slope /workspace/data/topographical_indices/slope/18E028_69050_4525_25.tif
# normalized slope /workspace/data/topographical_indices/slope/18E028_69075_4500_25.tif
# normalized slope /workspace/data/topographical_indices/slope/18E028_69075_4525_25.tif
# normalized slope /workspace/data/topographical_indices/slope/18E028_69100_4500_25.tif
# normalized slope /workspace/data/topographical_indices/slope/18E028_69100_4525_25.tif
# normalized slope /workspace/data/topographical_indices/slope/20E018_68750_4750_25.tif
# normalized slope /workspace/data/topographical_indices/slope/20E018_68750_4775_25.tif
# normalized slope /workspace/data/topographical_indices/slope/20E018_68750_4800_25.tif
# normalized slope /workspace/data/topographical_indices/slope/20E018_68775_4750_25.tif
# normalized slope /workspace/data/topographical_indices/slope/20E018_68775_4775_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/18E028_69000_4550_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/18E028_69025_4500_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/18E028_69050_4500_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/18E028_69050_4525_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/18E028_69075_4500_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/18E028_69075_4525_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/18E028_69100_4500_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/18E028_69100_4525_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/20E018_68750_4750_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/20E018_68750_4775_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/20E018_68750_4800_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/20E018_68775_4750_25.tif
# normalized hpmf /workspace/data/topographical_indices/hpmf/20E018_68775_4775_25.tif

# %% [markdown]
# ## Split tiles into image chips
# Make sure that the split target directory is empty. Otherwise the script will not start from 0.

# %%
list = os.listdir('/workspace/data/label_tiles/')
#list.sort()
print(list[0])
list2 = os.listdir('/workspace/data/topographical_indices_normalized/hillshade/')
#list2.sort()
print(list2[0])
# Out:
# 20E018_68750_4800_25.tif
# 18E028_69000_4550_25.tif

# %%
# Start by clearing directories of existing data
import os
import shutil

#shutil.rmtree('/workspace/data/split_data/')

os.mkdir('/workspace/data/split_data/')
os.mkdir('/workspace/data/split_data/labels/')
os.mkdir('/workspace/data/split_data/slope/')
os.mkdir('/workspace/data/split_data/hillshade/')
os.mkdir('/workspace/data/split_data/hpmf/')
        
# Split data
# Hillshade 
# !python /workspace/code/split_training_data.py /workspace/data/topographical_indices_normalized/hillshade/ /workspace/data/split_data/hillshade/ --tile_size 256
# Slope
# !python /workspace/code/split_training_data.py /workspace/data/topographical_indices_normalized/slope/ /workspace/data/split_data/slope/ --tile_size 256
# High pass median filter
# !python /workspace/code/split_training_data.py /workspace/data/topographical_indices_normalized/hpmf/ /workspace/data/split_data/hpmf/ --tile_size 256
# Labels
# !python /workspace/code/split_training_data.py /workspace/data/label_tiles/ /workspace/data/split_data/labels/ --tile_size 256
# Out:
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 0 files in the /workspace/data/split_data/hillshade/
# New image name will start with 1
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 506.57img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/18E028_69000_4550_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 400 files in the /workspace/data/split_data/hillshade/
# New image name will start with 401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 506.33img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/18E028_69025_4500_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 800 files in the /workspace/data/split_data/hillshade/
# New image name will start with 801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 491.07img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/18E028_69050_4500_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 1200 files in the /workspace/data/split_data/hillshade/
# New image name will start with 1201
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 498.57img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/18E028_69050_4525_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 1600 files in the /workspace/data/split_data/hillshade/
# New image name will start with 1601
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 513.66img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/18E028_69075_4500_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2000 files in the /workspace/data/split_data/hillshade/
# New image name will start with 2001
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 487.30img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/18E028_69075_4525_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2400 files in the /workspace/data/split_data/hillshade/
# New image name will start with 2401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 496.89img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/18E028_69100_4500_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2800 files in the /workspace/data/split_data/hillshade/
# New image name will start with 2801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 486.97img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/18E028_69100_4525_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 3200 files in the /workspace/data/split_data/hillshade/
# New image name will start with 3201
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 490.86img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/20E018_68750_4750_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 3600 files in the /workspace/data/split_data/hillshade/
# New image name will start with 3601
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 502.57img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/20E018_68750_4775_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4000 files in the /workspace/data/split_data/hillshade/
# New image name will start with 4001
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 516.33img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/20E018_68750_4800_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4400 files in the /workspace/data/split_data/hillshade/
# New image name will start with 4401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 486.42img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/20E018_68775_4750_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4800 files in the /workspace/data/split_data/hillshade/
# New image name will start with 4801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 478.39img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hillshade/20E018_68775_4775_25.tif are added at /workspace/data/split_data/hillshade/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 0 files in the /workspace/data/split_data/slope/
# New image name will start with 1
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 513.08img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/18E028_69000_4550_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 400 files in the /workspace/data/split_data/slope/
# New image name will start with 401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 478.77img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/18E028_69025_4500_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 800 files in the /workspace/data/split_data/slope/
# New image name will start with 801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 491.07img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/18E028_69050_4500_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 1200 files in the /workspace/data/split_data/slope/
# New image name will start with 1201
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 490.80img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/18E028_69050_4525_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 1600 files in the /workspace/data/split_data/slope/
# New image name will start with 1601
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 495.57img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/18E028_69075_4500_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2000 files in the /workspace/data/split_data/slope/
# New image name will start with 2001
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 498.11img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/18E028_69075_4525_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2400 files in the /workspace/data/split_data/slope/
# New image name will start with 2401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 474.34img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/18E028_69100_4500_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2800 files in the /workspace/data/split_data/slope/
# New image name will start with 2801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 475.71img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/18E028_69100_4525_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 3200 files in the /workspace/data/split_data/slope/
# New image name will start with 3201
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 497.01img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/20E018_68750_4750_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 3600 files in the /workspace/data/split_data/slope/
# New image name will start with 3601
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 495.42img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/20E018_68750_4775_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4000 files in the /workspace/data/split_data/slope/
# New image name will start with 4001
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 472.03img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/20E018_68750_4800_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4400 files in the /workspace/data/split_data/slope/
# New image name will start with 4401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 508.25img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/20E018_68775_4750_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4800 files in the /workspace/data/split_data/slope/
# New image name will start with 4801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 500.91img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/slope/20E018_68775_4775_25.tif are added at /workspace/data/split_data/slope/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 0 files in the /workspace/data/split_data/hpmf/
# New image name will start with 1
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 482.45img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/18E028_69000_4550_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 400 files in the /workspace/data/split_data/hpmf/
# New image name will start with 401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 498.15img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/18E028_69025_4500_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 800 files in the /workspace/data/split_data/hpmf/
# New image name will start with 801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 494.92img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/18E028_69050_4500_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 1200 files in the /workspace/data/split_data/hpmf/
# New image name will start with 1201
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 488.37img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/18E028_69050_4525_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 1600 files in the /workspace/data/split_data/hpmf/
# New image name will start with 1601
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 495.15img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/18E028_69075_4500_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2000 files in the /workspace/data/split_data/hpmf/
# New image name will start with 2001
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 491.22img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/18E028_69075_4525_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2400 files in the /workspace/data/split_data/hpmf/
# New image name will start with 2401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 492.08img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/18E028_69100_4500_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2800 files in the /workspace/data/split_data/hpmf/
# New image name will start with 2801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 485.35img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/18E028_69100_4525_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 3200 files in the /workspace/data/split_data/hpmf/
# New image name will start with 3201
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 481.73img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/20E018_68750_4750_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 3600 files in the /workspace/data/split_data/hpmf/
# New image name will start with 3601
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 479.54img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/20E018_68750_4775_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4000 files in the /workspace/data/split_data/hpmf/
# New image name will start with 4001
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 485.67img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/20E018_68750_4800_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4400 files in the /workspace/data/split_data/hpmf/
# New image name will start with 4401
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 484.53img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/20E018_68775_4750_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4800 files in the /workspace/data/split_data/hpmf/
# New image name will start with 4801
# Generating: 100%|███████████████████████████| 400/400 [00:00<00:00, 489.49img/s]
# 400 tiles sample of /workspace/data/topographical_indices_normalized/hpmf/20E018_68775_4775_25.tif are added at /workspace/data/split_data/hpmf/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 0 files in the /workspace/data/split_data/labels/
# New image name will start with 1
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 320.97img/s]
# 400 tiles sample of /workspace/data/label_tiles/18E028_69000_4550_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 400 files in the /workspace/data/split_data/labels/
# New image name will start with 401
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 305.00img/s]
# 400 tiles sample of /workspace/data/label_tiles/18E028_69025_4500_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 800 files in the /workspace/data/split_data/labels/
# New image name will start with 801
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 322.75img/s]
# 400 tiles sample of /workspace/data/label_tiles/18E028_69050_4500_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 1200 files in the /workspace/data/split_data/labels/
# New image name will start with 1201
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 338.12img/s]
# 400 tiles sample of /workspace/data/label_tiles/18E028_69050_4525_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 1600 files in the /workspace/data/split_data/labels/
# New image name will start with 1601
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 350.92img/s]
# 400 tiles sample of /workspace/data/label_tiles/18E028_69075_4500_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2000 files in the /workspace/data/split_data/labels/
# New image name will start with 2001
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 321.40img/s]
# 400 tiles sample of /workspace/data/label_tiles/18E028_69075_4525_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2400 files in the /workspace/data/split_data/labels/
# New image name will start with 2401
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 323.04img/s]
# 400 tiles sample of /workspace/data/label_tiles/18E028_69100_4500_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 2800 files in the /workspace/data/split_data/labels/
# New image name will start with 2801
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 322.35img/s]
# 400 tiles sample of /workspace/data/label_tiles/18E028_69100_4525_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 3200 files in the /workspace/data/split_data/labels/
# New image name will start with 3201
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 325.38img/s]
# 400 tiles sample of /workspace/data/label_tiles/20E018_68750_4750_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 3600 files in the /workspace/data/split_data/labels/
# New image name will start with 3601
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 321.70img/s]
# 400 tiles sample of /workspace/data/label_tiles/20E018_68750_4775_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4000 files in the /workspace/data/split_data/labels/
# New image name will start with 4001
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 325.14img/s]
# 400 tiles sample of /workspace/data/label_tiles/20E018_68750_4800_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4400 files in the /workspace/data/split_data/labels/
# New image name will start with 4401
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 322.82img/s]
# 400 tiles sample of /workspace/data/label_tiles/20E018_68775_4750_25.tif are added at /workspace/data/split_data/labels/
# Input Image File Shape (D, H, W):(1, 5000, 5000)
# crop_size=256, stride=256
# Padding Image File Shape (D, H, W):(1, 5120, 5120)
# There are 4800 files in the /workspace/data/split_data/labels/
# New image name will start with 4801
# Generating: 100%|███████████████████████████| 400/400 [00:01<00:00, 325.65img/s]
# 400 tiles sample of /workspace/data/label_tiles/20E018_68775_4775_25.tif are added at /workspace/data/split_data/labels/

# %% [markdown]
# ## Remove unlabeled chips
# Not all chips contains labeled pixels. These were removed before training

# %%
import glob
listoflabels = glob.glob('/workspace/data/split_data/labels/*.tif', recursive = True)
print('There are', (len(listoflabels)), 'chips before removing unlabeled chips')

# !python /workspace/code/remove_unlabled_chips.py 1 /workspace/data/split_data/labels/ /workspace/data/split_data/hillshade/ /workspace/data/split_data/slope/ /workspace/data/split_data/hpmf/

listoflabels = glob.glob('/workspace/data/split_data/labels/*.tif', recursive = True)
print('There are', (len(listoflabels)), 'chips after removing unlabeled chips')
# Out:
# There are 5200 chips before removing unlabeled chips
# There are 256 chips after removing unlabeled chips

# %% [markdown]
# ## Inspect some of the data

# %%
import glob
import matplotlib.pyplot as plt
import tifffile
plt.rcParams['figure.figsize'] = [16, 16]

labels = glob.glob('/workspace/data/split_data/labels/*.tif')
hillshade = glob.glob('/workspace/data/split_data/hillshade/*.tif')
hpmf = glob.glob('/workspace/data/split_data/hpmf/*.tif')
slope = glob.glob('/workspace/data/split_data/slope/*.tif')

f, axarr = plt.subplots(2,4)
axarr[1,0].imshow(tifffile.imread(labels[1]))
axarr[0,0].imshow(tifffile.imread(labels[4]))

axarr[1,1].imshow(tifffile.imread(hillshade[1]))
axarr[0,1].imshow(tifffile.imread(hillshade[4]))


axarr[1,2].imshow(tifffile.imread(hpmf[1]))
axarr[0,2].imshow(tifffile.imread(hpmf[4]))

axarr[1,3].imshow(tifffile.imread(slope[1]))
axarr[0,3].imshow(tifffile.imread(slope[4]))

# %% [markdown]
# # Evaluate U-net
# ## Train the model

# %%
# !python /workspace/code/train.py -I /workspace/data/split_data/hillshade/ -I /workspace/data/split_data/slope/ -I /workspace/data/split_data/hpmf/ /workspace/data/split_data/labels/ /workspace/data/logfiles/log1/ --seed=40 --epochs 10
# Out:
# 2022-04-29 10:52:48.152207: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# New Epoch
# New Epoch
# 2022-04-29 10:52:49.697828: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-29 10:52:49.728082: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:49.728227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1742] Found device 0 with properties:
# pciBusID: 0000:22:00.0 name: NVIDIA GeForce RTX 3070 computeCapability: 8.6
# coreClock: 1.725GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2022-04-29 10:52:49.728243: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-04-29 10:52:49.730403: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-04-29 10:52:49.731097: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-29 10:52:49.731273: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-29 10:52:49.733224: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-04-29 10:52:49.733713: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-04-29 10:52:49.733805: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-04-29 10:52:49.733902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:49.734053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:49.734137: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1884] Adding visible gpu devices: 0
# 2022-04-29 10:52:49.763740: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2900120000 Hz
# 2022-04-29 10:52:49.769618: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x48b5110 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-04-29 10:52:49.769656: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-04-29 10:52:50.019541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:50.019738: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4197840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-04-29 10:52:50.019756: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2022-04-29 10:52:50.019990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:50.020140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1742] Found device 0 with properties:
# pciBusID: 0000:22:00.0 name: NVIDIA GeForce RTX 3070 computeCapability: 8.6
# coreClock: 1.725GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2022-04-29 10:52:50.020164: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-04-29 10:52:50.020201: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-04-29 10:52:50.020215: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-29 10:52:50.020227: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-29 10:52:50.020239: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-04-29 10:52:50.020251: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-04-29 10:52:50.020264: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-04-29 10:52:50.020313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:50.020443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:50.020533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1884] Adding visible gpu devices: 0
# 2022-04-29 10:52:50.020553: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-04-29 10:52:50.255049: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1283] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-29 10:52:50.255103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1289]      0
# 2022-04-29 10:52:50.255110: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1302] 0:   N
# 2022-04-29 10:52:50.255340: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:50.255491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1079] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-29 10:52:50.255638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1428] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6158 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:22:00.0, compute capability: 8.6)
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.
# 2022-04-29 10:52:50.555704: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session started.
# 2022-04-29 10:52:50.555768: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1391] Profiler found 1 GPUs
# 2022-04-29 10:52:50.556439: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcupti.so.11.1
# 2022-04-29 10:52:50.650834: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1513] CUPTI activity buffer flushed
# WARNING:tensorflow:From /workspace/code/train.py:70: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# 2022-04-29 10:52:52.994436: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-04-29 10:52:54.526206: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-04-29 10:52:56.563877: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session started.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 2022-04-29 10:52:57.945651: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1513] CUPTI activity buffer flushed
# 2022-04-29 10:52:57.955636: I tensorflow/core/profiler/internal/gpu/device_tracer.cc:223]  GpuTracer has collected 7393 callback api events and 6656 activity events.
# 2022-04-29 10:52:58.084434: I tensorflow/core/profiler/rpc/client/save_profile.cc:176] Creating directory: /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58
# 2022-04-29 10:52:58.140651: I tensorflow/core/profiler/rpc/client/save_profile.cc:182] Dumped gzipped tool data for trace.json.gz to /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58/6c72dd7c67aa.trace.json.gz
# 2022-04-29 10:52:58.154818: E tensorflow/core/profiler/utils/hardware_type_utils.cc:61] Invalid GPU compute capability.
# 2022-04-29 10:52:58.206212: I tensorflow/core/profiler/rpc/client/save_profile.cc:176] Creating directory: /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58
# 2022-04-29 10:52:58.214071: I tensorflow/core/profiler/rpc/client/save_profile.cc:182] Dumped gzipped tool data for memory_profile.json.gz to /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58/6c72dd7c67aa.memory_profile.json.gz
# 2022-04-29 10:52:58.229492: I tensorflow/python/profiler/internal/profiler_wrapper.cc:111] Creating directory: /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58Dumped tool data for xplane.pb to /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58/6c72dd7c67aa.xplane.pb
# Dumped tool data for overview_page.pb to /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58/6c72dd7c67aa.overview_page.pb
# Dumped tool data for input_pipeline.pb to /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58/6c72dd7c67aa.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58/6c72dd7c67aa.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to /workspace/data/logfiles/log1/train/plugins/profile/2022_04_29_10_52_58/6c72dd7c67aa.kernel_stats.pb
#
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch
# New Epoch

# %% [markdown]
# ## Evaluate the model on test chips

# %% [markdown]
# ## Use the model for inference on test chips

# %% [markdown]
# # The Moon
# ## Data description

# %% [markdown]
# Impact creaters from the moon were used to pre-train the model. These creaters were digitised by NASA and are avalible from the Moon Crater Database v1 Robbins:https://astrogeology.usgs.gov/search/map/Moon/Research/Craters/lunar_crater_database_robbins_2018 The database contains approximately 1.3 million lunar impact craters and is approximately complete for all craters larger than about 1–2 km in diameter. Craters were manually identified and measured on Lunar Reconnaissance Orbiter (LRO) Camera (LROC) Wide-Angle Camera (WAC) images, in LRO Lunar Orbiter Laser Altimeter (LOLA) topography, SELENE Kaguya Terrain Camera (TC) images, and a merged LOLA+TC DTM.
#
#
# The Moon LRO LOLA DEM 118m v1 was used as digital elevation model. This digital elevation model  is based on data from the Lunar Orbiter Laser Altimeter, an instrument on the National Aeronautics and Space Agency (NASA) Lunar Reconnaissance Orbiter (LRO) spacecraft. The created DEM represents more than 6.5 billion measurements gathered between July 2009 and July 2013, adjusted for consistency in the coordinate system described below, and then converted to lunar radii.
# Source: https://astrogeology.usgs.gov/search/details/Moon/LRO/LOLA/Lunar_LRO_LOLA_Global_LDEM_118m_Mar2014/cub

# %% [markdown]
# ## Creater selection
# The average diameter of charcoal kilns in the trainig data was 21 meter with a standard deviation of +- 1.97 meter. Therefore creaters that were less than 19 meter were excluded. creaters larger than 23 meters were also excluded. It is possible that large creaters can be resampled down to 21 meter if they can be isolated.
#
# one pixel is 118 m so we are interested in craters between 2242 meter and 3776 meter.

# %%
import geopandas as gpd
all_creaters = gpd.read_file('/workspace/data/lunar_data/Catalog_Moon_Release_20180815_shapefile180/Catalog_Moon_Release_20180815_1kmPlus_180.shp')

# %%
print(len(all_creaters))
# Out:
# 1296796

# %%
#raw_data = gpd.read_file(original_craters)
def select_and_buffer(all_creaters, buffered_craters):
    raw_data = gpd.read_file(all_creaters)
    select = raw_data[(raw_data['DIAM_C_IM'].between(2.2, 3.8))]
    select['diameter_meter'] = select['DIAM_C_IM']/50 # I use 50 instead of 100 to get a slightly bigger buffer polygon
    print(len(select))
    # buffer points with field
    buffered_craters = select.buffer(distance=select['diameter_meter'])
    buffered_craters.to_file(all_creaters)
    
select_and_buffer('/workspace/data/lunar_data/Catalog_Moon_Release_20180815_shapefile180/Catalog_Moon_Release_20180815_1kmPlus_180.shp','/workspace/data/lunar_data/test50.shp')
# Out:
# /usr/local/lib/python3.8/dist-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# <ipython-input-87-91c4d2f2a747>:8: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   buffered_craters = select.buffer(distance=select['diameter_meter'])
# 236427
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-e069a9171358> in <module>
#       2 intersection_polygons_list = []
#       3
# ----> 4 for idx, row in gdf.iterrows():
#       5
#       6     main_poly_gdf = gdf.iloc[idx:idx+1, :]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoSeries' object has no attribute 'iterrows'

# %%
def buffer(row):
    return row.geometry.buffer(row.bufferid)

def select_craters(original_craters, selected_craters):
    raw_data = gpd.read_file(original_craters)
    select = raw_data[(raw_data['DIAM_C_IM'].between(2.2, 3.8))]
    
    #select.to_file(selected_craters)
    buffered = select.copy()
    buffered['geometry'] = buffered.apply(buffer, axis = 1)
    selected_craters = []
    for n, p in enumerate(buffered[:-1],1):
        if not any(p.overlaps(g) for g in buffered[n:]):
            non_overlapping_craters.append(str(p))
    print(len(selected_craters))   
select_creaters('/workspace/data/lunar_data/Catalog_Moon_Release_20180815_shapefile180/Catalog_Moon_Release_20180815_1kmPlus_180.shp')

# %%
selected_creaters = all_creaters[all_creaters['DIAM_C_IM'].between(2.2, 3.8)]
print(len(selected_creaters))
#selected_creaters.head()
# 1 pixel = 118 m
# DIAM_C_IM = m
# 38 pixels = 18
# Out:
# 236427

# %%
selected_creaters['DIAM_C_IM'].describe()
# Out:
# count    7587.000000
# mean       41.801468
# std        55.341096
# min        19.003900
# 25%        22.680150
# 50%        29.433600
# 75%        44.651350
# max      2491.870000
# Name: DIAM_C_IM, dtype: float64

# %% [markdown]
# ## Convert Lunar data to training data
# We can use the same method as before to convert the topographical data and field data to image chips that can be used for training. First we split the moon

# %%
# !python /workspace/code/create_labels.py /workspace/data/lunar_data/dem/ /workspace/data/lunar_data/Catalog_Moon_Release_20180815_shapefile180/Catalog_Moon_Release_20180815_1kmPlus_180.shp /workspace/data/lunar_data/labeled_moon/
# Out:
# ./whitebox_tools --run="VectorPolygonsToRaster" --input='/workspace/data/lunar_data/Catalog_Moon_Release_20180815_shapefile180/Catalog_Moon_Release_20180815_1kmPlus_180.shp' --field=class --output='/workspace/data/lunar_data/labeled_moon/Lunar_LRO_LOLA_Global_LDEM_118m_Mar2014.tif' --base='/workspace/data/lunar_data/dem/Lunar_LRO_LOLA_Global_LDEM_118m_Mar2014.tif'
#
# *************************************
# * Welcome to VectorPolygonsToRaster *
# * Powered by WhiteboxTools          *
# * www.whiteboxgeo.com               *
# *************************************
# Reading data...
# thread 'main' panicked at 'The input vector data must be of polygon base shape type.', whitebox-tools-app/src/main.rs:72:21
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace

# %%
fgrop 15-17
